# %% [markdown]
# # Churn Problem for Bank Customer
#
# ## Can you develop a machine learning model that can predict the customers who will leave the company?
#
# - The aim is to estimate whether a bank's customers leave the bank or not.
#
# - The event that defines the customer abandonment is the closing of the customer's bank account.
#
# ### Data Set Story:
#
# - It consists of 10000 observations and 12 variables.
# - Independent variables contain information about customers.
# - Dependent variable refers to customer abandonment.
#
# ### Features:
#
# - Surname: Surname
# - CreditScore: Credit score
# - Geography: Country (Germany / France / Spain)
# - Gender: Gender (Female / Male)
# - Age: Age
# - Tenure: How many years of customer
# - Balance: Balance
# - NumOfProducts: Bank product used
# - HasCrCard: Credit card status (0 = No, 1 = Yes)
# - IsActiveMember: Active membership status (0 = No, 1 = Yes)
# - EstimatedSalary: Estimated salary
# - Exited: Abandoned or not? (0 = No, 1 = Yes)

# %% [markdown]
# ## 1. Installing

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LogisticRegression  
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from xgboost import XGBClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score, GridSearchCV,train_test_split,cross_val_score
import itertools
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neighbors import LocalOutlierFactor # çok değişkenli aykırı gözlem incelemesi
from sklearn.preprocessing import scale,StandardScaler, MinMaxScaler,Normalizer,RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import  accuracy_score, f1_score, precision_score,confusion_matrix, recall_score, roc_auc_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=FutureWarning) 
warnings.filterwarnings("ignore", category=UserWarning) 

# %config InlineBackend.figure_format = 'retina'

# to display all columns and rows:
pd.set_option('display.max_columns', None); pd.set_option('display.max_rows', None);  # to display all columns and rows
pd.set_option('display.float_format', lambda x: '%.2f' % x) # The number of numbers that will be shown after the comma.
# Out:
# /kaggle/input/churn-for-bank-customers/churn.csv

# %%
df = pd.read_csv("../input/churn-for-bank-customers/churn.csv", index_col=0)
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#             Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1              0.00              1          1               1
# 2          83807.86              1          0               1
# 3         159660.80              3          1               0
# 4              0.00              2          0               0
# 5         125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %% [markdown]
# ## 2. EDA (Exploratory of Data Analysis)
# ### 2.1. Data Preperation

# %%
dependent_variable_name = "Exited"

# %%
def data_prepare():
    df_prep = df.copy()
    
    
    missing_value_len = df.isnull().any().sum()
    if missing_value_len == 0:
        print("No Missing Value")
    else:
        print("Investigate Missing Value, Missing Value : " + str(missing_value_len))
    print("\n")
    
    show_unique_count_variables(df = df_prep)
    
    
    df_prep['Tenure'] =  df_prep.Tenure.astype(np.float)
    df_prep['NumOfProducts'] =  df_prep.NumOfProducts.astype(np.float)
    return df_prep

# %% [markdown]
# Unique value data representation on all variables:

# %%
def show_unique_count_variables(df):
    for index, value in df.nunique().items():
        print(str(index) + "\n\t\t\t:" + str(value))

# %% [markdown]
# ### 2.2. Outliers Observe (LOF method and Supress)
# #### 2.2.1. Outlier Editing

# %%
def show_outliers(df):
    
    #tüm sütünları yukardan bakarak  outlier feature'ları gözlemleme
    
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    df_num_cols = df.select_dtypes(include=numerics)
    sns.set(font_scale = 0.7) 
    fig, axes = plt.subplots(nrows = 2, ncols = 5, gridspec_kw =  dict(hspace=0.3), figsize = (12,9))
    fig.tight_layout()
    for ax,col in zip(axes.flatten(), df_num_cols.columns):
        sns.boxplot(x = df_num_cols[col], color='green', ax = ax)
    fig.suptitle('Observing Outliers', color = 'r', fontsize = 14)

# %% [markdown]
# #### 2.2.2. Visualization of outliers according to the LOF method

# %%
def lof_observation(df):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    df_num_cols = df.select_dtypes(include=numerics)
    df_outlier = df_num_cols.astype("float64")
    clf = LocalOutlierFactor(n_neighbors = 20, contamination = 0.1)
    clf.fit_predict(df_outlier)
    df_scores = clf.negative_outlier_factor_
    scores_df = pd.DataFrame(np.sort(df_scores))
    
    scores_df.plot(stacked=True, xlim = [0,20], color='r', title='Visualization of outliers according to the LOF method', style = '.-');                # first 20 observe
    th_val = np.sort(df_scores)[2]
    outliers = df_scores > th_val
    df = df.drop(df_outlier[~outliers].index)
    df.shape
    return df

# %% [markdown]
# #### 2.2.3. Outiler suppression

# %%
def clear_outliers(df):
    
    #yas ve kredi_skoru baskılama
    
    Q1 = df["Age"].quantile(0.25)
    Q3 = df["Age"].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    print("When age and credit score is printed below lower score: ", lower, "and upper score: ", upper)
    df_outlier = df["Age"][(df["Age"] > upper)]
    df["Age"][df_outlier.index] = upper
    
    
    #kredi_skoru
    
    Q1 = df["CreditScore"].quantile(0.25)
    Q3 = df["CreditScore"].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    print("When age and credit score is printed above lower score: ", lower, "and upper score: ", upper)
    df_outlier = df["CreditScore"][(df["CreditScore"] < lower)]
    df["CreditScore"][df_outlier.index] = lower
    
    return df

# %% [markdown]
# #### 2.2.4. Outiler Process

# %%
def outlier_process(df):
    #show_outliers(df = df)
    df_outlier = lof_observation(df = df)
    df_outlier = clear_outliers(df = df_outlier)
    return df_outlier

# %% [markdown]
# ### 2.3. Data Analysis
# #### 2.3.1. Dependent variable distribution

# %%
def show_dependent_variable(df):
#     sns.countplot(data = df, x = dependent_variable_name, label = 'Count') \
#     .set_title(dependent_variable_name + ' dependent variable situation', fontsize = 18, color = 'r')
    fig, axarr = plt.subplots(2, 3, figsize=(18, 6))
    sns.countplot(x = 'Geography', hue = 'Exited',data = df, ax = axarr[0][0])
    sns.countplot(x = 'Gender', hue = 'Exited',data = df, ax = axarr[0][1])
    sns.countplot(x = 'HasCrCard', hue = 'Exited',data = df, ax = axarr[0][2])
    sns.countplot(x = 'IsActiveMember', hue = 'Exited',data = df, ax = axarr[1][0])
    sns.countplot(x = 'NumOfProducts', hue = 'Exited',data = df, ax = axarr[1][1])
    sns.countplot(x = 'Tenure', hue = 'Exited',data = df, ax = axarr[1][2])
    zero, one = df[dependent_variable_name].value_counts()
    print("Dependent variable distribution;")
    print(dependent_variable_name + " 0 count:", zero)
    print(dependent_variable_name + " 1 count:", one)

# %% [markdown]
# #### 2.3.2. Numeric columns distribution observation

# %%
def show_numeric_columns_distributions(df):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    df_num_cols = df.select_dtypes(include=numerics)
    columns = df_num_cols.columns[: len(df_num_cols.columns)]
    fig = plt.figure()
    fig.set_size_inches(18, 15)
    #plt.subplots(figsize=(22,22))
    length = len(columns)
    for i,j in itertools.zip_longest(columns, range(length)):
        plt.subplot((length / 2), 3, j+1)
        plt.subplots_adjust(wspace = 0.2, hspace = 0.5)
        df_num_cols[i].hist(bins = 20, edgecolor = 'black')
        plt.title(i)
    fig = fig.suptitle('Structures of numeric variables', color = 'r' ,fontsize = 18)
    plt.show()

# %% [markdown]
# #### 2.3.3. Status of other variables according to dependent variable

# %%
def show_dependent_variable_cross_others_distributions(df):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    df_dependent_var = df[df[dependent_variable_name] == 1]
    df_num_cols = df_dependent_var.select_dtypes(include = numerics)
    columns = df_num_cols.columns[: len(df_num_cols.columns)]
    
    fig = plt.figure()
    fig.set_size_inches(18, 15)
    length = len(columns)
    for i,j in itertools.zip_longest(columns, range(length)):
        plt.subplot((length / 2), 3, j+1)
        plt.subplots_adjust(wspace = 0.2, hspace = 0.5)
        df_num_cols[i].hist(bins = 20, edgecolor = 'black')
        plt.title(i)
    fig = fig.suptitle(dependent_variable_name + ' Status of other variables according to 1 dependent variable', color = 'r', fontsize = 18)
    plt.show()

# %% [markdown]
# #### 2.3.4. Categorical variables are observed according to the dependent variable

# %%
def show_dependent_variable_cross_categorical_distributions(df, categorical_columns):
    sns.set(font_scale = 0.7) 
    fig, axes = plt.subplots(nrows = int( len(categorical_columns) / 2 ) , ncols = 2, figsize = (7,9))
    fig.tight_layout()
    for ax,col in zip(axes.flatten(), categorical_columns):
        sns.countplot(x = df[col], hue = dependent_variable_name, data = df, ax = ax)
    fig.suptitle('Categorical variables are monitored according to the dependent variable', color = 'r', fontsize = 1)

# %% [markdown]
# #### 2.3.5. The main method that started all data analysis

# %%
def show_data_analysis(df):
    show_dependent_variable(df)
    show_numeric_columns_distributions(df)
    show_dependent_variable_cross_others_distributions(df)
    show_dependent_variable_cross_categorical_distributions(df = df_outlier, categorical_columns = ["Gender","Geography","HasCrCard","IsActiveMember"])

# %% [markdown]
# ## 3. Feature Engineering
# ### 3.1. Credit Score grouping ( min= 358 and max= 800)

# %%
def credit_score_table(row):
    
    credit_score = row.CreditScore
    if credit_score >= 300 and credit_score < 500:
        return "Very_Poor"
    elif credit_score >= 500 and credit_score < 601:
        return "Poor"
    elif credit_score >= 601 and credit_score < 661:
        return "Fair"
    elif credit_score >= 661 and credit_score < 781:
        return "Good"
    elif credit_score >= 851:
        return "Top"
    elif credit_score >= 781 and credit_score < 851:
        return "Excellent"
    elif credit_score < 300:
        return "Deep"

# %% [markdown]
# ### 3.2. Product utilization RATE by YEAR

# %%
def product_utilization_rate_by_year(row):
    number_of_products = row.NumOfProducts
    tenure = row.Tenure
    
    if number_of_products == 0:
        return 0
    
    if tenure == 0:
        return number_of_products
    
    rate = number_of_products / tenure
    return rate

# %% [markdown]
# ### 3.3. Product utilization rate by estimated SALARY

# %%
def product_utilization_rate_by_estimated_salary(row):
    number_of_products = row.number_of_products
    estimated_salary = row.EstimatedSalary
    
    if number_of_products == 0:
        return 0

    
    rate = number_of_products / estimated_salary
    return rate

# %% [markdown]
# ### 3.4. According to countries monthly average salaries

# %%
def countries_monthly_average_salaries(row):
    #brutto datas from  https://tr.wikipedia.org/wiki/Aylık_ortalama_ücretlerine_göre_Avrupa_ülkeleri_listesi
    fr = 3696    
    de = 4740
    sp = 2257
    salary = row.EstimatedSalary / 12
    country = row.Geography              # Germany, France and Spain
    
    if country == 'Germany':
        return salary / de
    elif country == "France":
        return salary / fr
    elif country == "Spain": 
        return salary / sp

# %% [markdown]
# ### 3.5. The main method that started all Feature Engineering

# %%
def feature_engineering(df, is_show_graph = False):
    df_fe = df.copy()
    
    #bakiye_maas_orani
    balance_salary_rate = 'balance_salary_rate'
    df_fe[balance_salary_rate] = df_fe.Balance / df_fe.EstimatedSalary
    
    #yila_gore_urun_kullanim_orani
    df_fe = df_fe.assign(product_utilization_rate_by_year=df_fe.apply(lambda x: product_utilization_rate_by_year(x), axis=1)) 
    
    #tahmini_maasa_gore_urun_kullanim_orani
    #df_fe = df_fe.assign(product_utilization_rate_by_estimated_salary = df_fe.apply(lambda x: product_utilization_rate_by_estimated_salary(x), axis=1)) 
    
    
    #musteri_yilina göre yaşa göre standardize edilmesi, oranlanmasi - ergenlik donemini cikariyoruz!
    tenure_rate_by_age = 'tenure_rate_by_age'
    df_fe[tenure_rate_by_age] = df_fe.Tenure / (df_fe.Age-17)
    
    #yaşa göre kredi_skoru standardize edilmesi, oranlanmasi - ergenlik donemini cikariyoruz!
    credit_score_rate_by_age = 'credit_score_rate_by_age'
    df_fe[credit_score_rate_by_age] = df_fe.CreditScore / (df_fe.Age-17)
    
    #maaşa gore kullanilan urun oran, oranlanmasi
    product_utilization_rate_by_salary = 'product_utilization_rate_by_salary'
    #df_fe[product_utilization_rate_by_salary] = df_fe.Tenure / (df_fe.EstimatedSalary)
   
    #maaşa göre kredi_skoru urun oran, oranlanmasi
    credit_score_rate_by_salary = 'credit_score_rate_by_salary'
    df_fe[credit_score_rate_by_salary] = df_fe.CreditScore / (df_fe.EstimatedSalary)
    
    #Feature Eng. oluşturulan değişkenlerin bağımlı değişkene göre grafikleri gösterilsin mi?
    if is_show_graph:
        fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (20,12))
        fig.tight_layout()
        sns.boxplot(y = balance_salary_rate, x = dependent_variable_name, hue = dependent_variable_name, data = df_fe, ax = axes[0][0])
        sns.boxplot(y = product_utilization_rate_by_year, x = dependent_variable_name, hue = dependent_variable_name, data = df_fe, ax = axes[0][1])
        #sns.countplot(x = credit_score_rate_by_age, hue = dependent_variable_name, data = df_fe, ax = axes[1][0])
        #sns.countplot(x = credit_score_rate_by_age, hue = dependent_variable_name, data = df_fe, ax = axes[1][1])
        plt.ylim(-1, 5)
    
    
    #feature engineering add- kredi_skor_tablosu
    df_fe = df_fe.assign(credit_score_table=df_fe.apply(lambda x: credit_score_table(x), axis=1))
    
    #feature engineering add- ulkelere ortalama  maas durum
    df_fe = df_fe.assign(countries_monthly_average_salaries = df_fe.apply(lambda x: countries_monthly_average_salaries(x), axis=1)) 
    
    return df_fe

# %% [markdown]
# ## 4. Data Encoding

# %%
# vucut_yag_orani, vucut_yag_orani_kategori,beden_kitle_kategori,insulin_kategori,kucuk_tansiyon_kategori

def data_encoding(df):
    df_model = df.copy()
    '''
    # It was attempted to reduce the number of 0 observations.
    churn_zero = df_model[df_model.apply(lambda x: True if x['Exited'] == 0 else False , axis=1)]
    df_train = churn_zero.sample(frac=0.1,random_state=100)
    df_model = df_model.drop(df_train.index)
    '''
    
    
    # >>>> Categorical columns <<<<<
    
    non_encoding_columns = ["Geography","HasCrCard","IsActiveMember","Gender","NumOfProducts","Tenure","credit_score_table"]
    
    df_non_encoding = df_model[non_encoding_columns]
    df_model = df_model.drop(non_encoding_columns,axis=1)
    
    
    df_encoding = df_non_encoding.copy()
    
    from sklearn.preprocessing import LabelEncoder
    encoder = LabelEncoder()
    df_encoding["gender_category"] = encoder.fit_transform(df_non_encoding.Gender)
    df_encoding["country_category"] = encoder.fit_transform(df_non_encoding.Geography)
    df_encoding["credit_score_category"] = encoder.fit_transform(df_non_encoding.credit_score_table)

    

    df_encoding.reset_index(drop=True, inplace=True)
    df_model.reset_index(drop=True, inplace=True)
    df_model = pd.concat([df_model,df_encoding],axis=1)

    df_model = df_model.drop(["Geography","Gender","CustomerId","Surname","credit_score_table","CreditScore","EstimatedSalary"],axis=1)
    df_model = df_model.reset_index()
    df_model = df_model.drop('index',axis=1)
    
    df_model.loc[df_model.HasCrCard == 0, 'credit_card_situation'] = -1
    df_model.loc[df_model.IsActiveMember == 0, 'is_active_member'] = -1
    return df_model

# %% [markdown]
# ## 5. Model Preparation

# %%
def model_prepare(df_model):
    y = df_model[dependent_variable_name]
    X = df_model.loc[:, df_model.columns != dependent_variable_name]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 12345)
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform (X_test)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### 5.1 Part of Data TRAIN

# %%
def data_training(X_train, X_test, y_train, y_test):

    models = []
    models.append(('LOGR',LogisticRegression()))
    models.append(('KNN',KNeighborsClassifier()))
    models.append(('CART',DecisionTreeClassifier()))
    models.append(('RF',RandomForestClassifier()))
    #models.append(('SVC',SVC()))
    models.append(('GBM',GradientBoostingClassifier()))
    models.append(('XGBoost',XGBClassifier()))
    models.append(('LightGBM',LGBMClassifier()))
    models.append(('CatBoost',CatBoostClassifier()))

    df_result = pd.DataFrame(columns=["model","accuracy_score","scale_method","0_precision","0_recall","1_precision","1_recall"])
    index = 0
    for name,model in models:
        model.fit(X_train,y_train)
        y_pred = model.predict(X_test)
        score = accuracy_score(y_test,y_pred)
        class_report = classification_report(y_test,y_pred,digits=2,output_dict=True)
        zero_report = class_report['0']
        one_report = class_report['1']
        df_result.at[index,['model','accuracy_score','scale_method',"0_precision","0_recall","1_precision","1_recall"]] = [name,score,"NA",zero_report['precision'],zero_report['recall'],one_report['precision'],one_report['recall']]
        index += 1
    return df_result.sort_values("accuracy_score",ascending=False)

# %% [markdown]
# ## 6. HELPing Functions

# %%
# Function to give best model score and parameters

def best_model(model):
    print(model.best_score_)    
    print(model.best_params_)
    print(model.best_estimator_)
    
def get_auc_scores(y_actual, method,method2):
    auc_score = roc_auc_score(y_actual, method); 
    fpr_df, tpr_df, _ = roc_curve(y_actual, method2); 
    return (auc_score, fpr_df, tpr_df)


from matplotlib import rc,rcParams
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.rcParams.update({'font.size': 16})
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, color="blue")
    plt.yticks(tick_marks, classes, color="blue")

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="red" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

''' inf yakalama
indices_to_keep = df_encoded.isin([np.nan, np.inf, -np.inf]).any(1)
df_encoded[indices_to_keep].astype(np.float64)
'''
# Out:
# ' inf yakalama\nindices_to_keep = df_encoded.isin([np.nan, np.inf, -np.inf]).any(1)\ndf_encoded[indices_to_keep].astype(np.float64)\n'

# %% [markdown]
# ## 7. Data Cleaning

# %%
df_prep = data_prepare()

df_outlier = outlier_process(df = df_prep)


show_data_analysis(df_prep)
show_outliers(df = df_outlier)
# Out:
# No Missing Value
#
#
# CustomerId
# 			:10000
# Surname
# 			:2932
# CreditScore
# 			:460
# Geography
# 			:3
# Gender
# 			:2
# Age
# 			:70
# Tenure
# 			:11
# Balance
# 			:6382
# NumOfProducts
# 			:4
# HasCrCard
# 			:2
# IsActiveMember
# 			:2
# EstimatedSalary
# 			:9999
# Exited
# 			:2
# When age and credit score is printed below lower score:  14.0 and upper score:  62.0
# When age and credit score is printed above lower score:  383.0 and upper score:  919.0
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Dependent variable distribution;
# Exited 0 count: 7963
# Exited 1 count: 2037

# %% [markdown]
# Let's see after feature engineering:

# %%
df_fe = feature_engineering(df = df_outlier)
df_fe.head(3)
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave       619.00    France  Female 42.00    2.00
# 2            15647311      Hill       608.00     Spain  Female 41.00    1.00
# 3            15619304      Onio       502.00    France  Female 42.00    8.00
#
#             Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1              0.00           1.00          1               1
# 2          83807.86           1.00          0               1
# 3         159660.80           3.00          1               0
#
#            EstimatedSalary  Exited  balance_salary_rate  \
# RowNumber
# 1                101348.88       1                 0.00
# 2                112542.58       0                 0.74
# 3                113931.57       1                 1.40
#
#            product_utilization_rate_by_year  tenure_rate_by_age  \
# RowNumber
# 1                                      0.50                0.08
# 2                                      1.00                0.04
# 3                                      0.38                0.32
#
#            credit_score_rate_by_age  credit_score_rate_by_salary  \
# RowNumber
# 1                             24.76                         0.01
# 2                             25.33                         0.01
# 3                             20.08                         0.00
#
#           credit_score_table  countries_monthly_average_salaries
# RowNumber
# 1                       Fair                                2.29
# 2                       Fair                                4.16
# 3                       Poor                                2.57

# %% [markdown]
# And see after data encoding:

# %%
df_encoded = data_encoding(df_fe)
df_encoded.drop(['credit_card_situation', 'is_active_member'], axis=1, inplace=True)
df_encoded.head(3)
# Out:
#     Age   Balance  Exited  balance_salary_rate  \
# 0 42.00      0.00       1                 0.00
# 1 41.00  83807.86       0                 0.74
# 2 42.00 159660.80       1                 1.40
#
#    product_utilization_rate_by_year  tenure_rate_by_age  \
# 0                              0.50                0.08
# 1                              1.00                0.04
# 2                              0.38                0.32
#
#    credit_score_rate_by_age  credit_score_rate_by_salary  \
# 0                     24.76                         0.01
# 1                     25.33                         0.01
# 2                     20.08                         0.00
#
#    countries_monthly_average_salaries  HasCrCard  IsActiveMember  \
# 0                                2.29          1               1
# 1                                4.16          0               1
# 2                                2.57          1               0
#
#    NumOfProducts  Tenure  gender_category  country_category  \
# 0           1.00    2.00                0                 0
# 1           1.00    1.00                0                 2
# 2           3.00    8.00                0                 0
#
#    credit_score_category
# 0                      1
# 1                      1
# 2                      3

# %% [markdown]
# Now, let's see correlation graph:

# %%
correlation = df_encoded.corr().abs()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, annot=True)
plt.show()

# %% [markdown]
# List of correlation scores:

# %%
corrs_results = df_encoded.corrwith(df_encoded["Exited"]).abs().nlargest(24)
corrs_results
# Out:
# Exited                               1.00
# Age                                  0.31
# IsActiveMember                       0.16
# credit_score_rate_by_age             0.14
# Balance                              0.12
# tenure_rate_by_age                   0.11
# gender_category                      0.11
# NumOfProducts                        0.05
# country_category                     0.04
# countries_monthly_average_salaries   0.03
# balance_salary_rate                  0.03
# credit_score_rate_by_salary          0.02
# credit_score_category                0.02
# Tenure                               0.01
# HasCrCard                            0.01
# product_utilization_rate_by_year     0.00
# dtype: float64

# %% [markdown]
# ## 8. Apply Model

# %%
# model_prepare test, train split 0.2
X_train, X_test, y_train, y_test = model_prepare(df_model = df_encoded)

# %% [markdown]
# ### 8.1. Logistic Regression Model
#
# Have a look with Logistic Regression.

# %%
logr_model = LogisticRegression().fit(X_train,y_train)
y_pred = logr_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred, digits=4))
print("Accuracy score of Logistic Regression: ", accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8212    0.9805    0.8938      1588
#            1     0.7019    0.1772    0.2829       412
#
#     accuracy                         0.8150      2000
#    macro avg     0.7616    0.5788    0.5884      2000
# weighted avg     0.7966    0.8150    0.7680      2000
#
# Accuracy score of Logistic Regression:  0.815

# %% [markdown]
# ### 8.2. Model Training
#
# This is for all LogisticRegression, RandomForestClassifier, GradientBoostingClassifier, XGBClassifier, and LGBMClassifier model objects:

# %%
training_result = data_training(X_train, X_test, y_train, y_test)
training_result
# Out:
# Learning rate set to 0.025031
# 0:	learn: 0.6724242	total: 69ms	remaining: 1m 8s
# 1:	learn: 0.6528787	total: 83.6ms	remaining: 41.7s
# 2:	learn: 0.6347511	total: 97.8ms	remaining: 32.5s
# 3:	learn: 0.6215314	total: 112ms	remaining: 28s
# 4:	learn: 0.6070445	total: 127ms	remaining: 25.2s
# 5:	learn: 0.5924679	total: 132ms	remaining: 21.8s
# 6:	learn: 0.5785152	total: 137ms	remaining: 19.4s
# 7:	learn: 0.5648807	total: 142ms	remaining: 17.6s
# 8:	learn: 0.5529239	total: 147ms	remaining: 16.2s
# 9:	learn: 0.5413860	total: 152ms	remaining: 15.1s
# 10:	learn: 0.5303889	total: 158ms	remaining: 14.2s
# 11:	learn: 0.5194985	total: 163ms	remaining: 13.4s
# 12:	learn: 0.5110660	total: 168ms	remaining: 12.7s
# 13:	learn: 0.5014714	total: 173ms	remaining: 12.2s
# 14:	learn: 0.4934572	total: 178ms	remaining: 11.7s
# 15:	learn: 0.4855108	total: 184ms	remaining: 11.3s
# 16:	learn: 0.4786334	total: 189ms	remaining: 10.9s
# 17:	learn: 0.4712011	total: 195ms	remaining: 10.7s
# 18:	learn: 0.4649324	total: 201ms	remaining: 10.4s
# 19:	learn: 0.4594278	total: 207ms	remaining: 10.1s
# 20:	learn: 0.4542804	total: 212ms	remaining: 9.86s
# 21:	learn: 0.4483451	total: 218ms	remaining: 9.7s
# 22:	learn: 0.4431427	total: 226ms	remaining: 9.59s
# 23:	learn: 0.4387160	total: 233ms	remaining: 9.48s
# 24:	learn: 0.4335625	total: 238ms	remaining: 9.29s
# 25:	learn: 0.4295232	total: 243ms	remaining: 9.12s
# 26:	learn: 0.4244576	total: 249ms	remaining: 8.96s
# 27:	learn: 0.4211586	total: 254ms	remaining: 8.81s
# 28:	learn: 0.4172014	total: 259ms	remaining: 8.67s
# 29:	learn: 0.4135863	total: 264ms	remaining: 8.53s
# 30:	learn: 0.4104597	total: 269ms	remaining: 8.41s
# 31:	learn: 0.4075129	total: 274ms	remaining: 8.29s
# 32:	learn: 0.4045925	total: 279ms	remaining: 8.18s
# 33:	learn: 0.4020203	total: 285ms	remaining: 8.11s
# 34:	learn: 0.3995489	total: 291ms	remaining: 8.01s
# 35:	learn: 0.3966533	total: 296ms	remaining: 7.92s
# 36:	learn: 0.3943899	total: 301ms	remaining: 7.83s
# 37:	learn: 0.3920936	total: 306ms	remaining: 7.75s
# 38:	learn: 0.3896426	total: 311ms	remaining: 7.66s
# 39:	learn: 0.3870772	total: 317ms	remaining: 7.6s
# 40:	learn: 0.3856182	total: 322ms	remaining: 7.53s
# 41:	learn: 0.3840372	total: 327ms	remaining: 7.46s
# 42:	learn: 0.3822182	total: 332ms	remaining: 7.4s
# 43:	learn: 0.3805370	total: 338ms	remaining: 7.33s
# 44:	learn: 0.3785520	total: 343ms	remaining: 7.27s
# 45:	learn: 0.3770567	total: 349ms	remaining: 7.23s
# 46:	learn: 0.3753597	total: 355ms	remaining: 7.19s
# 47:	learn: 0.3739810	total: 360ms	remaining: 7.15s
# 48:	learn: 0.3722470	total: 365ms	remaining: 7.09s
# 49:	learn: 0.3710147	total: 370ms	remaining: 7.04s
# 50:	learn: 0.3697158	total: 376ms	remaining: 7s
# 51:	learn: 0.3684406	total: 381ms	remaining: 6.95s
# 52:	learn: 0.3666775	total: 386ms	remaining: 6.9s
# 53:	learn: 0.3650015	total: 392ms	remaining: 6.87s
# 54:	learn: 0.3642009	total: 398ms	remaining: 6.83s
# 55:	learn: 0.3629800	total: 403ms	remaining: 6.79s
# 56:	learn: 0.3617484	total: 408ms	remaining: 6.75s
# 57:	learn: 0.3604988	total: 413ms	remaining: 6.7s
# 58:	learn: 0.3596011	total: 418ms	remaining: 6.66s
# 59:	learn: 0.3588775	total: 423ms	remaining: 6.63s
# 60:	learn: 0.3580828	total: 428ms	remaining: 6.59s
# 61:	learn: 0.3572153	total: 433ms	remaining: 6.55s
# 62:	learn: 0.3563990	total: 438ms	remaining: 6.52s
# 63:	learn: 0.3555401	total: 444ms	remaining: 6.49s
# 64:	learn: 0.3548061	total: 449ms	remaining: 6.46s
# 65:	learn: 0.3539965	total: 454ms	remaining: 6.43s
# 66:	learn: 0.3531178	total: 460ms	remaining: 6.4s
# 67:	learn: 0.3524483	total: 465ms	remaining: 6.37s
# 68:	learn: 0.3517635	total: 470ms	remaining: 6.34s
# 69:	learn: 0.3506291	total: 475ms	remaining: 6.31s
# 70:	learn: 0.3498624	total: 480ms	remaining: 6.28s
# 71:	learn: 0.3491503	total: 486ms	remaining: 6.26s
# 72:	learn: 0.3485113	total: 491ms	remaining: 6.23s
# 73:	learn: 0.3478761	total: 496ms	remaining: 6.21s
# 74:	learn: 0.3473380	total: 501ms	remaining: 6.18s
# 75:	learn: 0.3465231	total: 506ms	remaining: 6.15s
# 76:	learn: 0.3459606	total: 511ms	remaining: 6.13s
# 77:	learn: 0.3452663	total: 517ms	remaining: 6.11s
# 78:	learn: 0.3446226	total: 522ms	remaining: 6.08s
# 79:	learn: 0.3442096	total: 527ms	remaining: 6.06s
# 80:	learn: 0.3437233	total: 532ms	remaining: 6.04s
# 81:	learn: 0.3430676	total: 537ms	remaining: 6.01s
# 82:	learn: 0.3423041	total: 542ms	remaining: 5.99s
# 83:	learn: 0.3415118	total: 547ms	remaining: 5.97s
# 84:	learn: 0.3411120	total: 552ms	remaining: 5.95s
# 85:	learn: 0.3405499	total: 558ms	remaining: 5.93s
# 86:	learn: 0.3401204	total: 563ms	remaining: 5.91s
# 87:	learn: 0.3397536	total: 569ms	remaining: 5.89s
# 88:	learn: 0.3394981	total: 574ms	remaining: 5.87s
# 89:	learn: 0.3391511	total: 579ms	remaining: 5.85s
# 90:	learn: 0.3387113	total: 584ms	remaining: 5.83s
# 91:	learn: 0.3383508	total: 590ms	remaining: 5.83s
# 92:	learn: 0.3376449	total: 596ms	remaining: 5.81s
# 93:	learn: 0.3371924	total: 601ms	remaining: 5.79s
# 94:	learn: 0.3369093	total: 606ms	remaining: 5.77s
# 95:	learn: 0.3367804	total: 609ms	remaining: 5.74s
# 96:	learn: 0.3364156	total: 614ms	remaining: 5.72s
# 97:	learn: 0.3359798	total: 620ms	remaining: 5.7s
# 98:	learn: 0.3356694	total: 625ms	remaining: 5.68s
# 99:	learn: 0.3353914	total: 630ms	remaining: 5.67s
# 100:	learn: 0.3351279	total: 635ms	remaining: 5.65s
# 101:	learn: 0.3347240	total: 640ms	remaining: 5.63s
# 102:	learn: 0.3344529	total: 645ms	remaining: 5.62s
# 103:	learn: 0.3341165	total: 650ms	remaining: 5.6s
# 104:	learn: 0.3338853	total: 655ms	remaining: 5.58s
# 105:	learn: 0.3333754	total: 661ms	remaining: 5.57s
# 106:	learn: 0.3331468	total: 666ms	remaining: 5.56s
# 107:	learn: 0.3326274	total: 671ms	remaining: 5.54s
# 108:	learn: 0.3323914	total: 676ms	remaining: 5.53s
# 109:	learn: 0.3321498	total: 681ms	remaining: 5.51s
# 110:	learn: 0.3319663	total: 686ms	remaining: 5.5s
# 111:	learn: 0.3314725	total: 691ms	remaining: 5.48s
# 112:	learn: 0.3312925	total: 697ms	remaining: 5.47s
# 113:	learn: 0.3309470	total: 702ms	remaining: 5.45s
# 114:	learn: 0.3307229	total: 707ms	remaining: 5.44s
# 115:	learn: 0.3304284	total: 712ms	remaining: 5.43s
# 116:	learn: 0.3301714	total: 717ms	remaining: 5.41s
# 117:	learn: 0.3299963	total: 722ms	remaining: 5.4s
# 118:	learn: 0.3294502	total: 728ms	remaining: 5.39s
# 119:	learn: 0.3292887	total: 733ms	remaining: 5.37s
# 120:	learn: 0.3290843	total: 738ms	remaining: 5.36s
# 121:	learn: 0.3289521	total: 743ms	remaining: 5.35s
# 122:	learn: 0.3288227	total: 748ms	remaining: 5.33s
# 123:	learn: 0.3285344	total: 754ms	remaining: 5.32s
# 124:	learn: 0.3282932	total: 759ms	remaining: 5.31s
# 125:	learn: 0.3279981	total: 764ms	remaining: 5.3s
# 126:	learn: 0.3276100	total: 769ms	remaining: 5.29s
# 127:	learn: 0.3272410	total: 775ms	remaining: 5.28s
# 128:	learn: 0.3269527	total: 780ms	remaining: 5.26s
# 129:	learn: 0.3267394	total: 785ms	remaining: 5.25s
# 130:	learn: 0.3265648	total: 791ms	remaining: 5.25s
# 131:	learn: 0.3263601	total: 796ms	remaining: 5.23s
# 132:	learn: 0.3259270	total: 801ms	remaining: 5.22s
# 133:	learn: 0.3256730	total: 806ms	remaining: 5.21s
# 134:	learn: 0.3254784	total: 811ms	remaining: 5.2s
# 135:	learn: 0.3252593	total: 817ms	remaining: 5.19s
# 136:	learn: 0.3250646	total: 823ms	remaining: 5.19s
# 137:	learn: 0.3249399	total: 830ms	remaining: 5.18s
# 138:	learn: 0.3247946	total: 836ms	remaining: 5.18s
# 139:	learn: 0.3245230	total: 845ms	remaining: 5.19s
# 140:	learn: 0.3241600	total: 851ms	remaining: 5.18s
# 141:	learn: 0.3239900	total: 857ms	remaining: 5.18s
# 142:	learn: 0.3237632	total: 863ms	remaining: 5.17s
# 143:	learn: 0.3234769	total: 868ms	remaining: 5.16s
# 144:	learn: 0.3232020	total: 873ms	remaining: 5.15s
# 145:	learn: 0.3231085	total: 879ms	remaining: 5.14s
# 146:	learn: 0.3230297	total: 884ms	remaining: 5.13s
# 147:	learn: 0.3228748	total: 889ms	remaining: 5.12s
# 148:	learn: 0.3227328	total: 894ms	remaining: 5.11s
# 149:	learn: 0.3226302	total: 899ms	remaining: 5.09s
# 150:	learn: 0.3223195	total: 905ms	remaining: 5.09s
# 151:	learn: 0.3220923	total: 910ms	remaining: 5.08s
# 152:	learn: 0.3219757	total: 915ms	remaining: 5.07s
# 153:	learn: 0.3218333	total: 921ms	remaining: 5.06s
# 154:	learn: 0.3214944	total: 926ms	remaining: 5.05s
# 155:	learn: 0.3213917	total: 931ms	remaining: 5.04s
# 156:	learn: 0.3212118	total: 937ms	remaining: 5.03s
# 157:	learn: 0.3210220	total: 942ms	remaining: 5.02s
# 158:	learn: 0.3208660	total: 947ms	remaining: 5.01s
# 159:	learn: 0.3207266	total: 952ms	remaining: 5s
# 160:	learn: 0.3205433	total: 958ms	remaining: 4.99s
# 161:	learn: 0.3203221	total: 964ms	remaining: 4.99s
# 162:	learn: 0.3201165	total: 969ms	remaining: 4.98s
# 163:	learn: 0.3199298	total: 974ms	remaining: 4.97s
# 164:	learn: 0.3198132	total: 980ms	remaining: 4.96s
# 165:	learn: 0.3196246	total: 985ms	remaining: 4.95s
# 166:	learn: 0.3194938	total: 990ms	remaining: 4.94s
# 167:	learn: 0.3192098	total: 996ms	remaining: 4.93s
# 168:	learn: 0.3191091	total: 1s	remaining: 4.92s
# 169:	learn: 0.3189713	total: 1.01s	remaining: 4.91s
# 170:	learn: 0.3188181	total: 1.01s	remaining: 4.9s
# 171:	learn: 0.3186005	total: 1.02s	remaining: 4.89s
# 172:	learn: 0.3184223	total: 1.02s	remaining: 4.88s
# 173:	learn: 0.3182418	total: 1.03s	remaining: 4.88s
# 174:	learn: 0.3180975	total: 1.03s	remaining: 4.87s
# 175:	learn: 0.3178509	total: 1.04s	remaining: 4.86s
# 176:	learn: 0.3177280	total: 1.04s	remaining: 4.85s
# 177:	learn: 0.3175295	total: 1.05s	remaining: 4.84s
# 178:	learn: 0.3172798	total: 1.05s	remaining: 4.83s
# 179:	learn: 0.3172007	total: 1.06s	remaining: 4.82s
# 180:	learn: 0.3169807	total: 1.06s	remaining: 4.81s
# 181:	learn: 0.3168633	total: 1.07s	remaining: 4.8s
# 182:	learn: 0.3165673	total: 1.07s	remaining: 4.8s
# 183:	learn: 0.3164434	total: 1.08s	remaining: 4.79s
# 184:	learn: 0.3162678	total: 1.08s	remaining: 4.78s
# 185:	learn: 0.3160503	total: 1.09s	remaining: 4.77s
# 186:	learn: 0.3158649	total: 1.09s	remaining: 4.76s
# 187:	learn: 0.3157009	total: 1.1s	remaining: 4.75s
# 188:	learn: 0.3156181	total: 1.1s	remaining: 4.74s
# 189:	learn: 0.3155120	total: 1.11s	remaining: 4.74s
# 190:	learn: 0.3153100	total: 1.11s	remaining: 4.72s
# 191:	learn: 0.3151741	total: 1.12s	remaining: 4.72s
# 192:	learn: 0.3149541	total: 1.13s	remaining: 4.71s
# 193:	learn: 0.3147776	total: 1.13s	remaining: 4.7s
# 194:	learn: 0.3146076	total: 1.14s	remaining: 4.69s
# 195:	learn: 0.3145125	total: 1.14s	remaining: 4.68s
# 196:	learn: 0.3144797	total: 1.15s	remaining: 4.67s
# 197:	learn: 0.3143002	total: 1.15s	remaining: 4.66s
# 198:	learn: 0.3141332	total: 1.16s	remaining: 4.66s
# 199:	learn: 0.3140172	total: 1.16s	remaining: 4.65s
# 200:	learn: 0.3138955	total: 1.17s	remaining: 4.64s
# 201:	learn: 0.3137328	total: 1.17s	remaining: 4.63s
# 202:	learn: 0.3135963	total: 1.18s	remaining: 4.63s
# 203:	learn: 0.3135034	total: 1.19s	remaining: 4.63s
# 204:	learn: 0.3133235	total: 1.19s	remaining: 4.63s
# 205:	learn: 0.3132089	total: 1.2s	remaining: 4.62s
# 206:	learn: 0.3129414	total: 1.2s	remaining: 4.61s
# 207:	learn: 0.3127061	total: 1.21s	remaining: 4.6s
# 208:	learn: 0.3125747	total: 1.21s	remaining: 4.59s
# 209:	learn: 0.3124888	total: 1.22s	remaining: 4.58s
# 210:	learn: 0.3123887	total: 1.22s	remaining: 4.58s
# 211:	learn: 0.3122326	total: 1.23s	remaining: 4.57s
# 212:	learn: 0.3120453	total: 1.23s	remaining: 4.56s
# 213:	learn: 0.3118722	total: 1.24s	remaining: 4.55s
# 214:	learn: 0.3117584	total: 1.25s	remaining: 4.55s
# 215:	learn: 0.3115777	total: 1.26s	remaining: 4.57s
# 216:	learn: 0.3114784	total: 1.26s	remaining: 4.56s
# 217:	learn: 0.3113741	total: 1.27s	remaining: 4.56s
# 218:	learn: 0.3112450	total: 1.28s	remaining: 4.56s
# 219:	learn: 0.3110543	total: 1.28s	remaining: 4.55s
# 220:	learn: 0.3108453	total: 1.29s	remaining: 4.54s
# 221:	learn: 0.3106993	total: 1.29s	remaining: 4.54s
# 222:	learn: 0.3105161	total: 1.3s	remaining: 4.53s
# 223:	learn: 0.3104374	total: 1.31s	remaining: 4.53s
# 224:	learn: 0.3102904	total: 1.31s	remaining: 4.52s
# 225:	learn: 0.3101734	total: 1.32s	remaining: 4.51s
# 226:	learn: 0.3100147	total: 1.32s	remaining: 4.5s
# 227:	learn: 0.3098604	total: 1.33s	remaining: 4.5s
# 228:	learn: 0.3097472	total: 1.33s	remaining: 4.5s
# 229:	learn: 0.3096256	total: 1.34s	remaining: 4.49s
# 230:	learn: 0.3094497	total: 1.35s	remaining: 4.49s
# 231:	learn: 0.3093456	total: 1.35s	remaining: 4.48s
# 232:	learn: 0.3092844	total: 1.36s	remaining: 4.47s
# 233:	learn: 0.3091539	total: 1.36s	remaining: 4.46s
# 234:	learn: 0.3089590	total: 1.37s	remaining: 4.46s
# 235:	learn: 0.3088107	total: 1.38s	remaining: 4.45s
# 236:	learn: 0.3086980	total: 1.38s	remaining: 4.45s
# 237:	learn: 0.3084567	total: 1.39s	remaining: 4.44s
# 238:	learn: 0.3083874	total: 1.39s	remaining: 4.43s
# 239:	learn: 0.3082598	total: 1.4s	remaining: 4.42s
# 240:	learn: 0.3081284	total: 1.4s	remaining: 4.42s
# 241:	learn: 0.3079555	total: 1.41s	remaining: 4.41s
# 242:	learn: 0.3078487	total: 1.41s	remaining: 4.4s
# 243:	learn: 0.3076463	total: 1.42s	remaining: 4.39s
# 244:	learn: 0.3075380	total: 1.42s	remaining: 4.39s
# 245:	learn: 0.3073981	total: 1.43s	remaining: 4.38s
# 246:	learn: 0.3072212	total: 1.43s	remaining: 4.37s
# 247:	learn: 0.3070846	total: 1.44s	remaining: 4.36s
# 248:	learn: 0.3069520	total: 1.44s	remaining: 4.36s
# 249:	learn: 0.3067701	total: 1.45s	remaining: 4.35s
# 250:	learn: 0.3066678	total: 1.46s	remaining: 4.34s
# 251:	learn: 0.3065578	total: 1.46s	remaining: 4.34s
# 252:	learn: 0.3063982	total: 1.47s	remaining: 4.33s
# 253:	learn: 0.3061839	total: 1.47s	remaining: 4.33s
# 254:	learn: 0.3060610	total: 1.48s	remaining: 4.32s
# 255:	learn: 0.3058432	total: 1.48s	remaining: 4.31s
# 256:	learn: 0.3056802	total: 1.49s	remaining: 4.31s
# 257:	learn: 0.3055677	total: 1.49s	remaining: 4.3s
# 258:	learn: 0.3053967	total: 1.5s	remaining: 4.29s
# 259:	learn: 0.3053156	total: 1.5s	remaining: 4.28s
# 260:	learn: 0.3051931	total: 1.51s	remaining: 4.28s
# 261:	learn: 0.3050893	total: 1.51s	remaining: 4.27s
# 262:	learn: 0.3049509	total: 1.52s	remaining: 4.26s
# 263:	learn: 0.3048194	total: 1.52s	remaining: 4.25s
# 264:	learn: 0.3046261	total: 1.53s	remaining: 4.25s
# 265:	learn: 0.3044859	total: 1.54s	remaining: 4.24s
# 266:	learn: 0.3043962	total: 1.54s	remaining: 4.23s
# 267:	learn: 0.3042190	total: 1.55s	remaining: 4.22s
# 268:	learn: 0.3039993	total: 1.55s	remaining: 4.22s
# 269:	learn: 0.3038830	total: 1.56s	remaining: 4.21s
# 270:	learn: 0.3037491	total: 1.56s	remaining: 4.2s
# 271:	learn: 0.3036421	total: 1.57s	remaining: 4.2s
# 272:	learn: 0.3035076	total: 1.57s	remaining: 4.19s
# 273:	learn: 0.3033807	total: 1.58s	remaining: 4.18s
# 274:	learn: 0.3033018	total: 1.58s	remaining: 4.18s
# 275:	learn: 0.3031664	total: 1.59s	remaining: 4.17s
# 276:	learn: 0.3030081	total: 1.59s	remaining: 4.16s
# 277:	learn: 0.3027900	total: 1.6s	remaining: 4.15s
# 278:	learn: 0.3026594	total: 1.6s	remaining: 4.15s
# 279:	learn: 0.3025662	total: 1.61s	remaining: 4.14s
# 280:	learn: 0.3024422	total: 1.61s	remaining: 4.13s
# 281:	learn: 0.3023299	total: 1.62s	remaining: 4.12s
# 282:	learn: 0.3022432	total: 1.62s	remaining: 4.12s
# 283:	learn: 0.3020750	total: 1.63s	remaining: 4.11s
# 284:	learn: 0.3018979	total: 1.64s	remaining: 4.1s
# 285:	learn: 0.3017645	total: 1.64s	remaining: 4.09s
# 286:	learn: 0.3015886	total: 1.65s	remaining: 4.09s
# 287:	learn: 0.3014995	total: 1.65s	remaining: 4.08s
# 288:	learn: 0.3014010	total: 1.66s	remaining: 4.07s
# 289:	learn: 0.3012998	total: 1.66s	remaining: 4.07s
# 290:	learn: 0.3011924	total: 1.67s	remaining: 4.06s
# 291:	learn: 0.3010624	total: 1.67s	remaining: 4.05s
# 292:	learn: 0.3009441	total: 1.68s	remaining: 4.05s
# 293:	learn: 0.3008275	total: 1.68s	remaining: 4.04s
# 294:	learn: 0.3006718	total: 1.69s	remaining: 4.03s
# 295:	learn: 0.3005329	total: 1.69s	remaining: 4.03s
# 296:	learn: 0.3004388	total: 1.7s	remaining: 4.02s
# 297:	learn: 0.3002883	total: 1.7s	remaining: 4.01s
# 298:	learn: 0.3001794	total: 1.71s	remaining: 4s
# 299:	learn: 0.3000328	total: 1.71s	remaining: 4s
# 300:	learn: 0.2998852	total: 1.72s	remaining: 3.99s
# 301:	learn: 0.2997931	total: 1.72s	remaining: 3.98s
# 302:	learn: 0.2996711	total: 1.73s	remaining: 3.98s
# 303:	learn: 0.2995556	total: 1.73s	remaining: 3.97s
# 304:	learn: 0.2994352	total: 1.74s	remaining: 3.96s
# 305:	learn: 0.2992433	total: 1.74s	remaining: 3.96s
# 306:	learn: 0.2991600	total: 1.75s	remaining: 3.95s
# 307:	learn: 0.2990429	total: 1.75s	remaining: 3.94s
# 308:	learn: 0.2988951	total: 1.76s	remaining: 3.94s
# 309:	learn: 0.2987605	total: 1.76s	remaining: 3.93s
# 310:	learn: 0.2986153	total: 1.77s	remaining: 3.92s
# 311:	learn: 0.2984493	total: 1.78s	remaining: 3.92s
# 312:	learn: 0.2983406	total: 1.78s	remaining: 3.91s
# 313:	learn: 0.2981843	total: 1.79s	remaining: 3.9s
# 314:	learn: 0.2980462	total: 1.79s	remaining: 3.9s
# 315:	learn: 0.2979102	total: 1.8s	remaining: 3.89s
# 316:	learn: 0.2978211	total: 1.8s	remaining: 3.89s
# 317:	learn: 0.2977043	total: 1.81s	remaining: 3.88s
# 318:	learn: 0.2975461	total: 1.81s	remaining: 3.88s
# 319:	learn: 0.2973478	total: 1.82s	remaining: 3.87s
# 320:	learn: 0.2971906	total: 1.82s	remaining: 3.86s
# 321:	learn: 0.2970528	total: 1.83s	remaining: 3.85s
# 322:	learn: 0.2969585	total: 1.84s	remaining: 3.85s
# 323:	learn: 0.2968148	total: 1.84s	remaining: 3.84s
# 324:	learn: 0.2967434	total: 1.85s	remaining: 3.83s
# 325:	learn: 0.2966158	total: 1.85s	remaining: 3.83s
# 326:	learn: 0.2964794	total: 1.86s	remaining: 3.82s
# 327:	learn: 0.2963764	total: 1.86s	remaining: 3.81s
# 328:	learn: 0.2963129	total: 1.87s	remaining: 3.81s
# 329:	learn: 0.2962539	total: 1.87s	remaining: 3.8s
# 330:	learn: 0.2961860	total: 1.88s	remaining: 3.79s
# 331:	learn: 0.2960251	total: 1.88s	remaining: 3.79s
# 332:	learn: 0.2959165	total: 1.89s	remaining: 3.78s
# 333:	learn: 0.2957877	total: 1.89s	remaining: 3.77s
# 334:	learn: 0.2956691	total: 1.9s	remaining: 3.77s
# 335:	learn: 0.2955077	total: 1.9s	remaining: 3.76s
# 336:	learn: 0.2953854	total: 1.91s	remaining: 3.75s
# 337:	learn: 0.2952877	total: 1.91s	remaining: 3.75s
# 338:	learn: 0.2951677	total: 1.92s	remaining: 3.74s
# 339:	learn: 0.2950722	total: 1.92s	remaining: 3.73s
# 340:	learn: 0.2949390	total: 1.93s	remaining: 3.73s
# 341:	learn: 0.2948631	total: 1.93s	remaining: 3.72s
# 342:	learn: 0.2946532	total: 1.94s	remaining: 3.71s
# 343:	learn: 0.2944964	total: 1.94s	remaining: 3.71s
# 344:	learn: 0.2943504	total: 1.95s	remaining: 3.7s
# 345:	learn: 0.2941792	total: 1.95s	remaining: 3.69s
# 346:	learn: 0.2940814	total: 1.96s	remaining: 3.69s
# 347:	learn: 0.2939521	total: 1.97s	remaining: 3.68s
# 348:	learn: 0.2938804	total: 1.97s	remaining: 3.67s
# 349:	learn: 0.2937343	total: 1.98s	remaining: 3.67s
# 350:	learn: 0.2936611	total: 1.98s	remaining: 3.66s
# 351:	learn: 0.2935110	total: 1.99s	remaining: 3.66s
# 352:	learn: 0.2934071	total: 1.99s	remaining: 3.65s
# 353:	learn: 0.2932710	total: 2s	remaining: 3.64s
# 354:	learn: 0.2930899	total: 2s	remaining: 3.64s
# 355:	learn: 0.2929780	total: 2.01s	remaining: 3.63s
# 356:	learn: 0.2928709	total: 2.01s	remaining: 3.62s
# 357:	learn: 0.2927195	total: 2.02s	remaining: 3.62s
# 358:	learn: 0.2925827	total: 2.02s	remaining: 3.61s
# 359:	learn: 0.2924230	total: 2.03s	remaining: 3.6s
# 360:	learn: 0.2923317	total: 2.03s	remaining: 3.6s
# 361:	learn: 0.2922596	total: 2.04s	remaining: 3.59s
# 362:	learn: 0.2920311	total: 2.04s	remaining: 3.58s
# 363:	learn: 0.2918732	total: 2.05s	remaining: 3.58s
# 364:	learn: 0.2917241	total: 2.05s	remaining: 3.57s
# 365:	learn: 0.2916151	total: 2.06s	remaining: 3.57s
# 366:	learn: 0.2915530	total: 2.06s	remaining: 3.56s
# 367:	learn: 0.2914401	total: 2.07s	remaining: 3.55s
# 368:	learn: 0.2913734	total: 2.07s	remaining: 3.55s
# 369:	learn: 0.2912495	total: 2.08s	remaining: 3.54s
# 370:	learn: 0.2911090	total: 2.08s	remaining: 3.53s
# 371:	learn: 0.2909880	total: 2.09s	remaining: 3.53s
# 372:	learn: 0.2909018	total: 2.09s	remaining: 3.52s
# 373:	learn: 0.2908275	total: 2.1s	remaining: 3.52s
# 374:	learn: 0.2906950	total: 2.1s	remaining: 3.51s
# 375:	learn: 0.2905990	total: 2.11s	remaining: 3.5s
# 376:	learn: 0.2904910	total: 2.12s	remaining: 3.5s
# 377:	learn: 0.2903701	total: 2.12s	remaining: 3.49s
# 378:	learn: 0.2902368	total: 2.13s	remaining: 3.48s
# 379:	learn: 0.2901235	total: 2.13s	remaining: 3.48s
# 380:	learn: 0.2900550	total: 2.14s	remaining: 3.47s
# 381:	learn: 0.2899292	total: 2.15s	remaining: 3.47s
# 382:	learn: 0.2897522	total: 2.15s	remaining: 3.46s
# 383:	learn: 0.2896505	total: 2.16s	remaining: 3.46s
# 384:	learn: 0.2894919	total: 2.16s	remaining: 3.45s
# 385:	learn: 0.2893580	total: 2.17s	remaining: 3.45s
# 386:	learn: 0.2892218	total: 2.17s	remaining: 3.44s
# 387:	learn: 0.2891086	total: 2.18s	remaining: 3.43s
# 388:	learn: 0.2890218	total: 2.18s	remaining: 3.43s
# 389:	learn: 0.2889443	total: 2.19s	remaining: 3.42s
# 390:	learn: 0.2888946	total: 2.19s	remaining: 3.42s
# 391:	learn: 0.2887494	total: 2.2s	remaining: 3.41s
# 392:	learn: 0.2886263	total: 2.2s	remaining: 3.4s
# 393:	learn: 0.2885566	total: 2.21s	remaining: 3.4s
# 394:	learn: 0.2884316	total: 2.21s	remaining: 3.39s
# 395:	learn: 0.2883448	total: 2.22s	remaining: 3.39s
# 396:	learn: 0.2882493	total: 2.23s	remaining: 3.38s
# 397:	learn: 0.2880988	total: 2.23s	remaining: 3.37s
# 398:	learn: 0.2880080	total: 2.23s	remaining: 3.37s
# 399:	learn: 0.2879320	total: 2.24s	remaining: 3.36s
# 400:	learn: 0.2878124	total: 2.25s	remaining: 3.35s
# 401:	learn: 0.2876542	total: 2.25s	remaining: 3.35s
# 402:	learn: 0.2875108	total: 2.26s	remaining: 3.34s
# 403:	learn: 0.2874035	total: 2.26s	remaining: 3.34s
# 404:	learn: 0.2872708	total: 2.27s	remaining: 3.33s
# 405:	learn: 0.2871383	total: 2.27s	remaining: 3.32s
# 406:	learn: 0.2869682	total: 2.28s	remaining: 3.32s
# 407:	learn: 0.2868402	total: 2.28s	remaining: 3.31s
# 408:	learn: 0.2867467	total: 2.29s	remaining: 3.31s
# 409:	learn: 0.2866407	total: 2.29s	remaining: 3.3s
# 410:	learn: 0.2864867	total: 2.3s	remaining: 3.29s
# 411:	learn: 0.2864321	total: 2.3s	remaining: 3.29s
# 412:	learn: 0.2863259	total: 2.31s	remaining: 3.28s
# 413:	learn: 0.2862526	total: 2.31s	remaining: 3.28s
# 414:	learn: 0.2862003	total: 2.32s	remaining: 3.27s
# 415:	learn: 0.2861342	total: 2.33s	remaining: 3.26s
# 416:	learn: 0.2859976	total: 2.33s	remaining: 3.26s
# 417:	learn: 0.2858820	total: 2.33s	remaining: 3.25s
# 418:	learn: 0.2858045	total: 2.34s	remaining: 3.25s
# 419:	learn: 0.2856798	total: 2.35s	remaining: 3.24s
# 420:	learn: 0.2855749	total: 2.35s	remaining: 3.23s
# 421:	learn: 0.2854636	total: 2.36s	remaining: 3.23s
# 422:	learn: 0.2853364	total: 2.36s	remaining: 3.22s
# 423:	learn: 0.2852020	total: 2.37s	remaining: 3.22s
# 424:	learn: 0.2851342	total: 2.37s	remaining: 3.21s
# 425:	learn: 0.2850096	total: 2.38s	remaining: 3.21s
# 426:	learn: 0.2849322	total: 2.38s	remaining: 3.2s
# 427:	learn: 0.2848270	total: 2.39s	remaining: 3.19s
# 428:	learn: 0.2847135	total: 2.39s	remaining: 3.19s
# 429:	learn: 0.2846344	total: 2.4s	remaining: 3.18s
# 430:	learn: 0.2845641	total: 2.4s	remaining: 3.17s
# 431:	learn: 0.2844732	total: 2.41s	remaining: 3.17s
# 432:	learn: 0.2843428	total: 2.41s	remaining: 3.16s
# 433:	learn: 0.2842293	total: 2.42s	remaining: 3.16s
# 434:	learn: 0.2841519	total: 2.42s	remaining: 3.15s
# 435:	learn: 0.2839827	total: 2.43s	remaining: 3.14s
# 436:	learn: 0.2838457	total: 2.44s	remaining: 3.14s
# 437:	learn: 0.2837711	total: 2.44s	remaining: 3.13s
# 438:	learn: 0.2836418	total: 2.45s	remaining: 3.13s
# 439:	learn: 0.2834955	total: 2.45s	remaining: 3.12s
# 440:	learn: 0.2834406	total: 2.46s	remaining: 3.12s
# 441:	learn: 0.2833779	total: 2.47s	remaining: 3.12s
# 442:	learn: 0.2832643	total: 2.47s	remaining: 3.11s
# 443:	learn: 0.2831642	total: 2.48s	remaining: 3.1s
# 444:	learn: 0.2829631	total: 2.48s	remaining: 3.1s
# 445:	learn: 0.2828620	total: 2.49s	remaining: 3.09s
# 446:	learn: 0.2827909	total: 2.5s	remaining: 3.09s
# 447:	learn: 0.2826846	total: 2.5s	remaining: 3.08s
# 448:	learn: 0.2825442	total: 2.5s	remaining: 3.08s
# 449:	learn: 0.2824361	total: 2.51s	remaining: 3.07s
# 450:	learn: 0.2824246	total: 2.52s	remaining: 3.06s
# 451:	learn: 0.2822982	total: 2.52s	remaining: 3.06s
# 452:	learn: 0.2821914	total: 2.53s	remaining: 3.05s
# 453:	learn: 0.2820670	total: 2.53s	remaining: 3.04s
# 454:	learn: 0.2819621	total: 2.54s	remaining: 3.04s
# 455:	learn: 0.2818867	total: 2.54s	remaining: 3.03s
# 456:	learn: 0.2817634	total: 2.55s	remaining: 3.03s
# 457:	learn: 0.2816576	total: 2.55s	remaining: 3.02s
# 458:	learn: 0.2815661	total: 2.56s	remaining: 3.02s
# 459:	learn: 0.2814265	total: 2.56s	remaining: 3.01s
# 460:	learn: 0.2812793	total: 2.57s	remaining: 3s
# 461:	learn: 0.2812096	total: 2.57s	remaining: 3s
# 462:	learn: 0.2811017	total: 2.58s	remaining: 2.99s
# 463:	learn: 0.2810052	total: 2.59s	remaining: 2.99s
# 464:	learn: 0.2809020	total: 2.6s	remaining: 2.99s
# 465:	learn: 0.2807987	total: 2.6s	remaining: 2.98s
# 466:	learn: 0.2806927	total: 2.61s	remaining: 2.98s
# 467:	learn: 0.2806202	total: 2.61s	remaining: 2.97s
# 468:	learn: 0.2805211	total: 2.62s	remaining: 2.96s
# 469:	learn: 0.2804625	total: 2.62s	remaining: 2.96s
# 470:	learn: 0.2804044	total: 2.63s	remaining: 2.95s
# 471:	learn: 0.2803113	total: 2.63s	remaining: 2.94s
# 472:	learn: 0.2801895	total: 2.64s	remaining: 2.94s
# 473:	learn: 0.2801200	total: 2.64s	remaining: 2.93s
# 474:	learn: 0.2800097	total: 2.65s	remaining: 2.93s
# 475:	learn: 0.2799217	total: 2.65s	remaining: 2.92s
# 476:	learn: 0.2797947	total: 2.66s	remaining: 2.91s
# 477:	learn: 0.2796596	total: 2.66s	remaining: 2.91s
# 478:	learn: 0.2795214	total: 2.67s	remaining: 2.9s
# 479:	learn: 0.2794732	total: 2.67s	remaining: 2.9s
# 480:	learn: 0.2793839	total: 2.68s	remaining: 2.89s
# 481:	learn: 0.2792991	total: 2.68s	remaining: 2.88s
# 482:	learn: 0.2791911	total: 2.69s	remaining: 2.88s
# 483:	learn: 0.2790667	total: 2.69s	remaining: 2.87s
# 484:	learn: 0.2789935	total: 2.7s	remaining: 2.87s
# 485:	learn: 0.2789736	total: 2.71s	remaining: 2.86s
# 486:	learn: 0.2788587	total: 2.71s	remaining: 2.85s
# 487:	learn: 0.2787167	total: 2.71s	remaining: 2.85s
# 488:	learn: 0.2785639	total: 2.72s	remaining: 2.84s
# 489:	learn: 0.2784651	total: 2.73s	remaining: 2.84s
# 490:	learn: 0.2784527	total: 2.73s	remaining: 2.83s
# 491:	learn: 0.2783911	total: 2.74s	remaining: 2.83s
# 492:	learn: 0.2782938	total: 2.74s	remaining: 2.82s
# 493:	learn: 0.2781943	total: 2.75s	remaining: 2.81s
# 494:	learn: 0.2780533	total: 2.75s	remaining: 2.81s
# 495:	learn: 0.2779359	total: 2.76s	remaining: 2.8s
# 496:	learn: 0.2778368	total: 2.77s	remaining: 2.8s
# 497:	learn: 0.2778137	total: 2.77s	remaining: 2.79s
# 498:	learn: 0.2776871	total: 2.78s	remaining: 2.79s
# 499:	learn: 0.2775916	total: 2.78s	remaining: 2.78s
# 500:	learn: 0.2775410	total: 2.79s	remaining: 2.78s
# 501:	learn: 0.2774049	total: 2.79s	remaining: 2.77s
# 502:	learn: 0.2773232	total: 2.8s	remaining: 2.77s
# 503:	learn: 0.2771851	total: 2.8s	remaining: 2.76s
# 504:	learn: 0.2770849	total: 2.81s	remaining: 2.75s
# 505:	learn: 0.2769715	total: 2.81s	remaining: 2.75s
# 506:	learn: 0.2768835	total: 2.82s	remaining: 2.74s
# 507:	learn: 0.2767518	total: 2.83s	remaining: 2.74s
# 508:	learn: 0.2766541	total: 2.83s	remaining: 2.73s
# 509:	learn: 0.2764892	total: 2.84s	remaining: 2.73s
# 510:	learn: 0.2763885	total: 2.84s	remaining: 2.72s
# 511:	learn: 0.2763690	total: 2.85s	remaining: 2.71s
# 512:	learn: 0.2763299	total: 2.85s	remaining: 2.71s
# 513:	learn: 0.2762163	total: 2.86s	remaining: 2.7s
# 514:	learn: 0.2760840	total: 2.86s	remaining: 2.69s
# 515:	learn: 0.2760361	total: 2.87s	remaining: 2.69s
# 516:	learn: 0.2759529	total: 2.87s	remaining: 2.68s
# 517:	learn: 0.2758643	total: 2.88s	remaining: 2.68s
# 518:	learn: 0.2757933	total: 2.88s	remaining: 2.67s
# 519:	learn: 0.2756818	total: 2.89s	remaining: 2.67s
# 520:	learn: 0.2755984	total: 2.89s	remaining: 2.66s
# 521:	learn: 0.2754420	total: 2.9s	remaining: 2.65s
# 522:	learn: 0.2753196	total: 2.9s	remaining: 2.65s
# 523:	learn: 0.2752194	total: 2.91s	remaining: 2.64s
# 524:	learn: 0.2751240	total: 2.91s	remaining: 2.64s
# 525:	learn: 0.2749743	total: 2.92s	remaining: 2.63s
# 526:	learn: 0.2748062	total: 2.92s	remaining: 2.62s
# 527:	learn: 0.2746708	total: 2.93s	remaining: 2.62s
# 528:	learn: 0.2746261	total: 2.93s	remaining: 2.61s
# 529:	learn: 0.2745520	total: 2.94s	remaining: 2.61s
# 530:	learn: 0.2744268	total: 2.94s	remaining: 2.6s
# 531:	learn: 0.2743214	total: 2.95s	remaining: 2.6s
# 532:	learn: 0.2742251	total: 2.96s	remaining: 2.59s
# 533:	learn: 0.2741229	total: 2.96s	remaining: 2.58s
# 534:	learn: 0.2739750	total: 2.97s	remaining: 2.58s
# 535:	learn: 0.2738481	total: 2.97s	remaining: 2.57s
# 536:	learn: 0.2737819	total: 2.98s	remaining: 2.57s
# 537:	learn: 0.2736730	total: 2.98s	remaining: 2.56s
# 538:	learn: 0.2735728	total: 2.99s	remaining: 2.55s
# 539:	learn: 0.2734736	total: 2.99s	remaining: 2.55s
# 540:	learn: 0.2733664	total: 3s	remaining: 2.54s
# 541:	learn: 0.2732393	total: 3s	remaining: 2.54s
# 542:	learn: 0.2731604	total: 3.01s	remaining: 2.53s
# 543:	learn: 0.2730698	total: 3.01s	remaining: 2.52s
# 544:	learn: 0.2730001	total: 3.02s	remaining: 2.52s
# 545:	learn: 0.2729137	total: 3.02s	remaining: 2.51s
# 546:	learn: 0.2728054	total: 3.03s	remaining: 2.51s
# 547:	learn: 0.2726553	total: 3.03s	remaining: 2.5s
# 548:	learn: 0.2725267	total: 3.04s	remaining: 2.5s
# 549:	learn: 0.2724417	total: 3.04s	remaining: 2.49s
# 550:	learn: 0.2723448	total: 3.05s	remaining: 2.48s
# 551:	learn: 0.2722291	total: 3.05s	remaining: 2.48s
# 552:	learn: 0.2721569	total: 3.06s	remaining: 2.47s
# 553:	learn: 0.2720233	total: 3.06s	remaining: 2.47s
# 554:	learn: 0.2719102	total: 3.07s	remaining: 2.46s
# 555:	learn: 0.2717511	total: 3.08s	remaining: 2.46s
# 556:	learn: 0.2716475	total: 3.08s	remaining: 2.45s
# 557:	learn: 0.2716125	total: 3.09s	remaining: 2.44s
# 558:	learn: 0.2715197	total: 3.09s	remaining: 2.44s
# 559:	learn: 0.2713918	total: 3.1s	remaining: 2.43s
# 560:	learn: 0.2712702	total: 3.11s	remaining: 2.43s
# 561:	learn: 0.2711788	total: 3.11s	remaining: 2.42s
# 562:	learn: 0.2710859	total: 3.12s	remaining: 2.42s
# 563:	learn: 0.2709846	total: 3.12s	remaining: 2.41s
# 564:	learn: 0.2708943	total: 3.13s	remaining: 2.41s
# 565:	learn: 0.2707712	total: 3.13s	remaining: 2.4s
# 566:	learn: 0.2706720	total: 3.14s	remaining: 2.4s
# 567:	learn: 0.2705483	total: 3.14s	remaining: 2.39s
# 568:	learn: 0.2704515	total: 3.15s	remaining: 2.38s
# 569:	learn: 0.2703110	total: 3.15s	remaining: 2.38s
# 570:	learn: 0.2702313	total: 3.16s	remaining: 2.37s
# 571:	learn: 0.2701392	total: 3.17s	remaining: 2.37s
# 572:	learn: 0.2700215	total: 3.18s	remaining: 2.37s
# 573:	learn: 0.2699256	total: 3.19s	remaining: 2.37s
# 574:	learn: 0.2697832	total: 3.2s	remaining: 2.36s
# 575:	learn: 0.2697098	total: 3.2s	remaining: 2.36s
# 576:	learn: 0.2695957	total: 3.21s	remaining: 2.35s
# 577:	learn: 0.2694973	total: 3.22s	remaining: 2.35s
# 578:	learn: 0.2693892	total: 3.22s	remaining: 2.34s
# 579:	learn: 0.2693000	total: 3.23s	remaining: 2.34s
# 580:	learn: 0.2692214	total: 3.23s	remaining: 2.33s
# 581:	learn: 0.2691345	total: 3.24s	remaining: 2.32s
# 582:	learn: 0.2690469	total: 3.24s	remaining: 2.32s
# 583:	learn: 0.2689855	total: 3.25s	remaining: 2.31s
# 584:	learn: 0.2688881	total: 3.25s	remaining: 2.31s
# 585:	learn: 0.2687964	total: 3.26s	remaining: 2.3s
# 586:	learn: 0.2686950	total: 3.26s	remaining: 2.29s
# 587:	learn: 0.2685921	total: 3.27s	remaining: 2.29s
# 588:	learn: 0.2684648	total: 3.27s	remaining: 2.28s
# 589:	learn: 0.2683647	total: 3.28s	remaining: 2.28s
# 590:	learn: 0.2682553	total: 3.28s	remaining: 2.27s
# 591:	learn: 0.2681711	total: 3.29s	remaining: 2.27s
# 592:	learn: 0.2680735	total: 3.29s	remaining: 2.26s
# 593:	learn: 0.2679898	total: 3.3s	remaining: 2.25s
# 594:	learn: 0.2679269	total: 3.3s	remaining: 2.25s
# 595:	learn: 0.2678510	total: 3.31s	remaining: 2.24s
# 596:	learn: 0.2677477	total: 3.31s	remaining: 2.24s
# 597:	learn: 0.2676828	total: 3.32s	remaining: 2.23s
# 598:	learn: 0.2675678	total: 3.32s	remaining: 2.23s
# 599:	learn: 0.2675009	total: 3.33s	remaining: 2.22s
# 600:	learn: 0.2673972	total: 3.33s	remaining: 2.21s
# 601:	learn: 0.2673338	total: 3.34s	remaining: 2.21s
# 602:	learn: 0.2672776	total: 3.35s	remaining: 2.2s
# 603:	learn: 0.2671318	total: 3.35s	remaining: 2.2s
# 604:	learn: 0.2669899	total: 3.35s	remaining: 2.19s
# 605:	learn: 0.2669275	total: 3.36s	remaining: 2.18s
# 606:	learn: 0.2668046	total: 3.37s	remaining: 2.18s
# 607:	learn: 0.2667139	total: 3.37s	remaining: 2.17s
# 608:	learn: 0.2666403	total: 3.38s	remaining: 2.17s
# 609:	learn: 0.2665338	total: 3.38s	remaining: 2.16s
# 610:	learn: 0.2664302	total: 3.39s	remaining: 2.15s
# 611:	learn: 0.2663120	total: 3.39s	remaining: 2.15s
# 612:	learn: 0.2661738	total: 3.4s	remaining: 2.14s
# 613:	learn: 0.2660922	total: 3.4s	remaining: 2.14s
# 614:	learn: 0.2659954	total: 3.41s	remaining: 2.13s
# 615:	learn: 0.2659062	total: 3.41s	remaining: 2.13s
# 616:	learn: 0.2658715	total: 3.42s	remaining: 2.12s
# 617:	learn: 0.2657577	total: 3.42s	remaining: 2.12s
# 618:	learn: 0.2656390	total: 3.43s	remaining: 2.11s
# 619:	learn: 0.2655529	total: 3.43s	remaining: 2.1s
# 620:	learn: 0.2654539	total: 3.44s	remaining: 2.1s
# 621:	learn: 0.2653627	total: 3.44s	remaining: 2.09s
# 622:	learn: 0.2652513	total: 3.45s	remaining: 2.09s
# 623:	learn: 0.2651872	total: 3.45s	remaining: 2.08s
# 624:	learn: 0.2651152	total: 3.46s	remaining: 2.07s
# 625:	learn: 0.2650127	total: 3.46s	remaining: 2.07s
# 626:	learn: 0.2648927	total: 3.47s	remaining: 2.06s
# 627:	learn: 0.2648100	total: 3.47s	remaining: 2.06s
# 628:	learn: 0.2646862	total: 3.48s	remaining: 2.05s
# 629:	learn: 0.2645836	total: 3.48s	remaining: 2.05s
# 630:	learn: 0.2645029	total: 3.49s	remaining: 2.04s
# 631:	learn: 0.2643737	total: 3.5s	remaining: 2.04s
# 632:	learn: 0.2642739	total: 3.51s	remaining: 2.03s
# 633:	learn: 0.2642419	total: 3.51s	remaining: 2.03s
# 634:	learn: 0.2641577	total: 3.52s	remaining: 2.02s
# 635:	learn: 0.2640380	total: 3.52s	remaining: 2.02s
# 636:	learn: 0.2639559	total: 3.53s	remaining: 2.01s
# 637:	learn: 0.2638910	total: 3.54s	remaining: 2.01s
# 638:	learn: 0.2637978	total: 3.54s	remaining: 2s
# 639:	learn: 0.2636454	total: 3.55s	remaining: 2s
# 640:	learn: 0.2635483	total: 3.55s	remaining: 1.99s
# 641:	learn: 0.2634618	total: 3.56s	remaining: 1.98s
# 642:	learn: 0.2633508	total: 3.56s	remaining: 1.98s
# 643:	learn: 0.2632787	total: 3.57s	remaining: 1.97s
# 644:	learn: 0.2631309	total: 3.57s	remaining: 1.97s
# 645:	learn: 0.2630347	total: 3.58s	remaining: 1.96s
# 646:	learn: 0.2629725	total: 3.58s	remaining: 1.96s
# 647:	learn: 0.2628615	total: 3.59s	remaining: 1.95s
# 648:	learn: 0.2627059	total: 3.59s	remaining: 1.94s
# 649:	learn: 0.2626168	total: 3.6s	remaining: 1.94s
# 650:	learn: 0.2625054	total: 3.6s	remaining: 1.93s
# 651:	learn: 0.2623821	total: 3.61s	remaining: 1.93s
# 652:	learn: 0.2622486	total: 3.61s	remaining: 1.92s
# 653:	learn: 0.2621894	total: 3.62s	remaining: 1.92s
# 654:	learn: 0.2620762	total: 3.63s	remaining: 1.91s
# 655:	learn: 0.2619813	total: 3.63s	remaining: 1.9s
# 656:	learn: 0.2618819	total: 3.63s	remaining: 1.9s
# 657:	learn: 0.2617941	total: 3.64s	remaining: 1.89s
# 658:	learn: 0.2616696	total: 3.65s	remaining: 1.89s
# 659:	learn: 0.2615960	total: 3.65s	remaining: 1.88s
# 660:	learn: 0.2614778	total: 3.66s	remaining: 1.88s
# 661:	learn: 0.2613717	total: 3.66s	remaining: 1.87s
# 662:	learn: 0.2612371	total: 3.67s	remaining: 1.86s
# 663:	learn: 0.2611403	total: 3.67s	remaining: 1.86s
# 664:	learn: 0.2610384	total: 3.68s	remaining: 1.85s
# 665:	learn: 0.2609266	total: 3.68s	remaining: 1.85s
# 666:	learn: 0.2608611	total: 3.69s	remaining: 1.84s
# 667:	learn: 0.2607926	total: 3.69s	remaining: 1.83s
# 668:	learn: 0.2606791	total: 3.7s	remaining: 1.83s
# 669:	learn: 0.2606422	total: 3.7s	remaining: 1.82s
# 670:	learn: 0.2605679	total: 3.71s	remaining: 1.82s
# 671:	learn: 0.2604932	total: 3.71s	remaining: 1.81s
# 672:	learn: 0.2603935	total: 3.72s	remaining: 1.81s
# 673:	learn: 0.2603103	total: 3.73s	remaining: 1.8s
# 674:	learn: 0.2602308	total: 3.73s	remaining: 1.8s
# 675:	learn: 0.2601581	total: 3.74s	remaining: 1.79s
# 676:	learn: 0.2600531	total: 3.74s	remaining: 1.78s
# 677:	learn: 0.2599445	total: 3.75s	remaining: 1.78s
# 678:	learn: 0.2598140	total: 3.75s	remaining: 1.77s
# 679:	learn: 0.2597066	total: 3.76s	remaining: 1.77s
# 680:	learn: 0.2596268	total: 3.76s	remaining: 1.76s
# 681:	learn: 0.2594987	total: 3.77s	remaining: 1.76s
# 682:	learn: 0.2594305	total: 3.77s	remaining: 1.75s
# 683:	learn: 0.2593568	total: 3.78s	remaining: 1.75s
# 684:	learn: 0.2592320	total: 3.79s	remaining: 1.74s
# 685:	learn: 0.2591116	total: 3.79s	remaining: 1.73s
# 686:	learn: 0.2590806	total: 3.79s	remaining: 1.73s
# 687:	learn: 0.2590071	total: 3.8s	remaining: 1.72s
# 688:	learn: 0.2588720	total: 3.81s	remaining: 1.72s
# 689:	learn: 0.2587830	total: 3.81s	remaining: 1.71s
# 690:	learn: 0.2586496	total: 3.82s	remaining: 1.71s
# 691:	learn: 0.2585963	total: 3.82s	remaining: 1.7s
# 692:	learn: 0.2584737	total: 3.83s	remaining: 1.7s
# 693:	learn: 0.2583675	total: 3.83s	remaining: 1.69s
# 694:	learn: 0.2583044	total: 3.84s	remaining: 1.68s
# 695:	learn: 0.2581267	total: 3.84s	remaining: 1.68s
# 696:	learn: 0.2580187	total: 3.85s	remaining: 1.67s
# 697:	learn: 0.2578910	total: 3.85s	remaining: 1.67s
# 698:	learn: 0.2577925	total: 3.86s	remaining: 1.66s
# 699:	learn: 0.2577060	total: 3.86s	remaining: 1.66s
# 700:	learn: 0.2576385	total: 3.87s	remaining: 1.65s
# 701:	learn: 0.2576046	total: 3.87s	remaining: 1.64s
# 702:	learn: 0.2575763	total: 3.88s	remaining: 1.64s
# 703:	learn: 0.2574670	total: 3.88s	remaining: 1.63s
# 704:	learn: 0.2573930	total: 3.89s	remaining: 1.63s
# 705:	learn: 0.2572749	total: 3.89s	remaining: 1.62s
# 706:	learn: 0.2572152	total: 3.9s	remaining: 1.62s
# 707:	learn: 0.2572032	total: 3.9s	remaining: 1.61s
# 708:	learn: 0.2570770	total: 3.91s	remaining: 1.6s
# 709:	learn: 0.2568849	total: 3.91s	remaining: 1.6s
# 710:	learn: 0.2567466	total: 3.92s	remaining: 1.59s
# 711:	learn: 0.2566157	total: 3.93s	remaining: 1.59s
# 712:	learn: 0.2565577	total: 3.93s	remaining: 1.58s
# 713:	learn: 0.2564494	total: 3.94s	remaining: 1.58s
# 714:	learn: 0.2563575	total: 3.94s	remaining: 1.57s
# 715:	learn: 0.2562478	total: 3.95s	remaining: 1.56s
# 716:	learn: 0.2561113	total: 3.95s	remaining: 1.56s
# 717:	learn: 0.2560426	total: 3.96s	remaining: 1.55s
# 718:	learn: 0.2559835	total: 3.96s	remaining: 1.55s
# 719:	learn: 0.2558343	total: 3.97s	remaining: 1.54s
# 720:	learn: 0.2556724	total: 3.97s	remaining: 1.54s
# 721:	learn: 0.2556098	total: 3.98s	remaining: 1.53s
# 722:	learn: 0.2555289	total: 3.98s	remaining: 1.53s
# 723:	learn: 0.2554078	total: 3.99s	remaining: 1.52s
# 724:	learn: 0.2553385	total: 3.99s	remaining: 1.51s
# 725:	learn: 0.2551999	total: 4s	remaining: 1.51s
# 726:	learn: 0.2551056	total: 4s	remaining: 1.5s
# 727:	learn: 0.2550460	total: 4.01s	remaining: 1.5s
# 728:	learn: 0.2549415	total: 4.01s	remaining: 1.49s
# 729:	learn: 0.2548371	total: 4.02s	remaining: 1.49s
# 730:	learn: 0.2546606	total: 4.03s	remaining: 1.48s
# 731:	learn: 0.2545343	total: 4.03s	remaining: 1.48s
# 732:	learn: 0.2544770	total: 4.04s	remaining: 1.47s
# 733:	learn: 0.2542976	total: 4.04s	remaining: 1.46s
# 734:	learn: 0.2542144	total: 4.04s	remaining: 1.46s
# 735:	learn: 0.2541156	total: 4.05s	remaining: 1.45s
# 736:	learn: 0.2539770	total: 4.06s	remaining: 1.45s
# 737:	learn: 0.2538852	total: 4.07s	remaining: 1.44s
# 738:	learn: 0.2537953	total: 4.07s	remaining: 1.44s
# 739:	learn: 0.2537133	total: 4.08s	remaining: 1.43s
# 740:	learn: 0.2536129	total: 4.08s	remaining: 1.43s
# 741:	learn: 0.2535207	total: 4.09s	remaining: 1.42s
# 742:	learn: 0.2534781	total: 4.09s	remaining: 1.42s
# 743:	learn: 0.2533343	total: 4.1s	remaining: 1.41s
# 744:	learn: 0.2532244	total: 4.1s	remaining: 1.4s
# 745:	learn: 0.2531570	total: 4.11s	remaining: 1.4s
# 746:	learn: 0.2530369	total: 4.11s	remaining: 1.39s
# 747:	learn: 0.2529400	total: 4.12s	remaining: 1.39s
# 748:	learn: 0.2528195	total: 4.12s	remaining: 1.38s
# 749:	learn: 0.2526999	total: 4.13s	remaining: 1.38s
# 750:	learn: 0.2525853	total: 4.14s	remaining: 1.37s
# 751:	learn: 0.2525037	total: 4.14s	remaining: 1.36s
# 752:	learn: 0.2524166	total: 4.15s	remaining: 1.36s
# 753:	learn: 0.2522877	total: 4.15s	remaining: 1.35s
# 754:	learn: 0.2522109	total: 4.16s	remaining: 1.35s
# 755:	learn: 0.2521345	total: 4.16s	remaining: 1.34s
# 756:	learn: 0.2520249	total: 4.17s	remaining: 1.34s
# 757:	learn: 0.2519027	total: 4.17s	remaining: 1.33s
# 758:	learn: 0.2518051	total: 4.18s	remaining: 1.33s
# 759:	learn: 0.2517301	total: 4.18s	remaining: 1.32s
# 760:	learn: 0.2516574	total: 4.19s	remaining: 1.31s
# 761:	learn: 0.2515540	total: 4.19s	remaining: 1.31s
# 762:	learn: 0.2514382	total: 4.2s	remaining: 1.3s
# 763:	learn: 0.2513454	total: 4.2s	remaining: 1.3s
# 764:	learn: 0.2512396	total: 4.21s	remaining: 1.29s
# 765:	learn: 0.2511138	total: 4.21s	remaining: 1.29s
# 766:	learn: 0.2509830	total: 4.22s	remaining: 1.28s
# 767:	learn: 0.2508883	total: 4.22s	remaining: 1.28s
# 768:	learn: 0.2508078	total: 4.23s	remaining: 1.27s
# 769:	learn: 0.2507132	total: 4.24s	remaining: 1.26s
# 770:	learn: 0.2506288	total: 4.24s	remaining: 1.26s
# 771:	learn: 0.2505200	total: 4.25s	remaining: 1.25s
# 772:	learn: 0.2504774	total: 4.25s	remaining: 1.25s
# 773:	learn: 0.2503496	total: 4.26s	remaining: 1.24s
# 774:	learn: 0.2502724	total: 4.26s	remaining: 1.24s
# 775:	learn: 0.2501743	total: 4.27s	remaining: 1.23s
# 776:	learn: 0.2500872	total: 4.27s	remaining: 1.23s
# 777:	learn: 0.2499837	total: 4.28s	remaining: 1.22s
# 778:	learn: 0.2499201	total: 4.28s	remaining: 1.21s
# 779:	learn: 0.2498153	total: 4.29s	remaining: 1.21s
# 780:	learn: 0.2497271	total: 4.29s	remaining: 1.2s
# 781:	learn: 0.2496506	total: 4.3s	remaining: 1.2s
# 782:	learn: 0.2495577	total: 4.3s	remaining: 1.19s
# 783:	learn: 0.2494935	total: 4.31s	remaining: 1.19s
# 784:	learn: 0.2494091	total: 4.31s	remaining: 1.18s
# 785:	learn: 0.2493230	total: 4.32s	remaining: 1.18s
# 786:	learn: 0.2492566	total: 4.33s	remaining: 1.17s
# 787:	learn: 0.2491874	total: 4.33s	remaining: 1.16s
# 788:	learn: 0.2490985	total: 4.33s	remaining: 1.16s
# 789:	learn: 0.2490340	total: 4.34s	remaining: 1.15s
# 790:	learn: 0.2489087	total: 4.34s	remaining: 1.15s
# 791:	learn: 0.2488665	total: 4.35s	remaining: 1.14s
# 792:	learn: 0.2487962	total: 4.36s	remaining: 1.14s
# 793:	learn: 0.2486309	total: 4.36s	remaining: 1.13s
# 794:	learn: 0.2485114	total: 4.37s	remaining: 1.13s
# 795:	learn: 0.2483979	total: 4.37s	remaining: 1.12s
# 796:	learn: 0.2482826	total: 4.38s	remaining: 1.11s
# 797:	learn: 0.2481268	total: 4.38s	remaining: 1.11s
# 798:	learn: 0.2480524	total: 4.39s	remaining: 1.1s
# 799:	learn: 0.2479378	total: 4.39s	remaining: 1.1s
# 800:	learn: 0.2478561	total: 4.4s	remaining: 1.09s
# 801:	learn: 0.2478037	total: 4.4s	remaining: 1.09s
# 802:	learn: 0.2477101	total: 4.41s	remaining: 1.08s
# 803:	learn: 0.2475455	total: 4.41s	remaining: 1.07s
# 804:	learn: 0.2474503	total: 4.42s	remaining: 1.07s
# 805:	learn: 0.2473722	total: 4.42s	remaining: 1.06s
# 806:	learn: 0.2472949	total: 4.43s	remaining: 1.06s
# 807:	learn: 0.2471890	total: 4.43s	remaining: 1.05s
# 808:	learn: 0.2471270	total: 4.44s	remaining: 1.05s
# 809:	learn: 0.2470528	total: 4.44s	remaining: 1.04s
# 810:	learn: 0.2469726	total: 4.45s	remaining: 1.04s
# 811:	learn: 0.2468561	total: 4.45s	remaining: 1.03s
# 812:	learn: 0.2467692	total: 4.46s	remaining: 1.02s
# 813:	learn: 0.2466642	total: 4.46s	remaining: 1.02s
# 814:	learn: 0.2465970	total: 4.47s	remaining: 1.01s
# 815:	learn: 0.2464693	total: 4.47s	remaining: 1.01s
# 816:	learn: 0.2463304	total: 4.48s	remaining: 1s
# 817:	learn: 0.2462637	total: 4.49s	remaining: 998ms
# 818:	learn: 0.2461829	total: 4.49s	remaining: 992ms
# 819:	learn: 0.2461310	total: 4.5s	remaining: 987ms
# 820:	learn: 0.2459948	total: 4.5s	remaining: 981ms
# 821:	learn: 0.2458907	total: 4.5s	remaining: 976ms
# 822:	learn: 0.2457444	total: 4.51s	remaining: 970ms
# 823:	learn: 0.2456783	total: 4.52s	remaining: 965ms
# 824:	learn: 0.2455466	total: 4.52s	remaining: 959ms
# 825:	learn: 0.2454160	total: 4.53s	remaining: 954ms
# 826:	learn: 0.2452877	total: 4.53s	remaining: 948ms
# 827:	learn: 0.2451855	total: 4.54s	remaining: 943ms
# 828:	learn: 0.2450693	total: 4.55s	remaining: 938ms
# 829:	learn: 0.2449380	total: 4.55s	remaining: 933ms
# 830:	learn: 0.2448568	total: 4.56s	remaining: 928ms
# 831:	learn: 0.2447966	total: 4.57s	remaining: 923ms
# 832:	learn: 0.2447068	total: 4.58s	remaining: 917ms
# 833:	learn: 0.2445808	total: 4.58s	remaining: 912ms
# 834:	learn: 0.2444574	total: 4.59s	remaining: 907ms
# 835:	learn: 0.2443905	total: 4.59s	remaining: 901ms
# 836:	learn: 0.2443420	total: 4.6s	remaining: 896ms
# 837:	learn: 0.2442399	total: 4.61s	remaining: 891ms
# 838:	learn: 0.2441207	total: 4.61s	remaining: 885ms
# 839:	learn: 0.2440630	total: 4.62s	remaining: 880ms
# 840:	learn: 0.2439841	total: 4.63s	remaining: 875ms
# 841:	learn: 0.2438632	total: 4.63s	remaining: 869ms
# 842:	learn: 0.2437330	total: 4.64s	remaining: 864ms
# 843:	learn: 0.2436174	total: 4.65s	remaining: 859ms
# 844:	learn: 0.2435629	total: 4.66s	remaining: 854ms
# 845:	learn: 0.2434095	total: 4.66s	remaining: 849ms
# 846:	learn: 0.2433001	total: 4.67s	remaining: 844ms
# 847:	learn: 0.2431821	total: 4.68s	remaining: 838ms
# 848:	learn: 0.2430408	total: 4.68s	remaining: 833ms
# 849:	learn: 0.2429093	total: 4.69s	remaining: 827ms
# 850:	learn: 0.2428265	total: 4.69s	remaining: 822ms
# 851:	learn: 0.2427325	total: 4.7s	remaining: 816ms
# 852:	learn: 0.2425634	total: 4.7s	remaining: 811ms
# 853:	learn: 0.2424744	total: 4.71s	remaining: 805ms
# 854:	learn: 0.2424335	total: 4.71s	remaining: 800ms
# 855:	learn: 0.2423652	total: 4.72s	remaining: 794ms
# 856:	learn: 0.2422671	total: 4.72s	remaining: 788ms
# 857:	learn: 0.2421635	total: 4.73s	remaining: 783ms
# 858:	learn: 0.2420976	total: 4.74s	remaining: 777ms
# 859:	learn: 0.2420351	total: 4.74s	remaining: 772ms
# 860:	learn: 0.2419697	total: 4.75s	remaining: 766ms
# 861:	learn: 0.2418506	total: 4.75s	remaining: 761ms
# 862:	learn: 0.2417790	total: 4.76s	remaining: 755ms
# 863:	learn: 0.2416710	total: 4.76s	remaining: 750ms
# 864:	learn: 0.2415552	total: 4.77s	remaining: 744ms
# 865:	learn: 0.2414127	total: 4.77s	remaining: 739ms
# 866:	learn: 0.2413494	total: 4.78s	remaining: 733ms
# 867:	learn: 0.2412695	total: 4.78s	remaining: 727ms
# 868:	learn: 0.2411293	total: 4.79s	remaining: 722ms
# 869:	learn: 0.2410659	total: 4.79s	remaining: 716ms
# 870:	learn: 0.2409428	total: 4.8s	remaining: 711ms
# 871:	learn: 0.2407973	total: 4.8s	remaining: 705ms
# 872:	learn: 0.2407217	total: 4.81s	remaining: 700ms
# 873:	learn: 0.2405987	total: 4.82s	remaining: 694ms
# 874:	learn: 0.2404796	total: 4.82s	remaining: 689ms
# 875:	learn: 0.2403089	total: 4.83s	remaining: 683ms
# 876:	learn: 0.2402427	total: 4.83s	remaining: 678ms
# 877:	learn: 0.2401487	total: 4.84s	remaining: 672ms
# 878:	learn: 0.2400258	total: 4.84s	remaining: 666ms
# 879:	learn: 0.2399039	total: 4.85s	remaining: 661ms
# 880:	learn: 0.2397851	total: 4.85s	remaining: 655ms
# 881:	learn: 0.2397118	total: 4.86s	remaining: 650ms
# 882:	learn: 0.2396419	total: 4.86s	remaining: 644ms
# 883:	learn: 0.2395902	total: 4.87s	remaining: 639ms
# 884:	learn: 0.2394525	total: 4.87s	remaining: 633ms
# 885:	learn: 0.2393489	total: 4.88s	remaining: 628ms
# 886:	learn: 0.2392801	total: 4.88s	remaining: 622ms
# 887:	learn: 0.2391633	total: 4.89s	remaining: 616ms
# 888:	learn: 0.2390092	total: 4.89s	remaining: 611ms
# 889:	learn: 0.2388700	total: 4.9s	remaining: 605ms
# 890:	learn: 0.2387465	total: 4.9s	remaining: 600ms
# 891:	learn: 0.2386429	total: 4.91s	remaining: 594ms
# 892:	learn: 0.2385127	total: 4.92s	remaining: 589ms
# 893:	learn: 0.2384400	total: 4.92s	remaining: 583ms
# 894:	learn: 0.2383902	total: 4.92s	remaining: 578ms
# 895:	learn: 0.2382805	total: 4.93s	remaining: 572ms
# 896:	learn: 0.2381867	total: 4.93s	remaining: 567ms
# 897:	learn: 0.2381403	total: 4.94s	remaining: 561ms
# 898:	learn: 0.2380187	total: 4.95s	remaining: 556ms
# 899:	learn: 0.2379092	total: 4.95s	remaining: 550ms
# 900:	learn: 0.2377615	total: 4.96s	remaining: 545ms
# 901:	learn: 0.2376968	total: 4.96s	remaining: 539ms
# 902:	learn: 0.2376296	total: 4.97s	remaining: 534ms
# 903:	learn: 0.2375491	total: 4.97s	remaining: 528ms
# 904:	learn: 0.2374890	total: 4.98s	remaining: 522ms
# 905:	learn: 0.2374247	total: 4.98s	remaining: 517ms
# 906:	learn: 0.2372772	total: 4.99s	remaining: 511ms
# 907:	learn: 0.2371685	total: 4.99s	remaining: 506ms
# 908:	learn: 0.2370240	total: 5s	remaining: 500ms
# 909:	learn: 0.2369510	total: 5s	remaining: 495ms
# 910:	learn: 0.2368612	total: 5.01s	remaining: 489ms
# 911:	learn: 0.2368030	total: 5.01s	remaining: 484ms
# 912:	learn: 0.2367573	total: 5.02s	remaining: 478ms
# 913:	learn: 0.2367311	total: 5.02s	remaining: 473ms
# 914:	learn: 0.2366241	total: 5.03s	remaining: 467ms
# 915:	learn: 0.2365463	total: 5.03s	remaining: 462ms
# 916:	learn: 0.2364370	total: 5.04s	remaining: 456ms
# 917:	learn: 0.2363463	total: 5.04s	remaining: 451ms
# 918:	learn: 0.2362444	total: 5.05s	remaining: 445ms
# 919:	learn: 0.2361903	total: 5.05s	remaining: 440ms
# 920:	learn: 0.2361231	total: 5.06s	remaining: 434ms
# 921:	learn: 0.2360460	total: 5.07s	remaining: 429ms
# 922:	learn: 0.2359506	total: 5.07s	remaining: 423ms
# 923:	learn: 0.2358183	total: 5.08s	remaining: 418ms
# 924:	learn: 0.2357267	total: 5.08s	remaining: 412ms
# 925:	learn: 0.2356377	total: 5.09s	remaining: 406ms
# 926:	learn: 0.2355313	total: 5.09s	remaining: 401ms
# 927:	learn: 0.2353946	total: 5.1s	remaining: 396ms
# 928:	learn: 0.2353103	total: 5.11s	remaining: 390ms
# 929:	learn: 0.2352108	total: 5.12s	remaining: 385ms
# 930:	learn: 0.2351357	total: 5.13s	remaining: 380ms
# 931:	learn: 0.2350778	total: 5.13s	remaining: 374ms
# 932:	learn: 0.2349674	total: 5.14s	remaining: 369ms
# 933:	learn: 0.2349090	total: 5.14s	remaining: 364ms
# 934:	learn: 0.2348223	total: 5.15s	remaining: 358ms
# 935:	learn: 0.2347283	total: 5.16s	remaining: 353ms
# 936:	learn: 0.2346623	total: 5.17s	remaining: 347ms
# 937:	learn: 0.2345763	total: 5.17s	remaining: 342ms
# 938:	learn: 0.2344782	total: 5.18s	remaining: 336ms
# 939:	learn: 0.2343727	total: 5.18s	remaining: 331ms
# 940:	learn: 0.2343056	total: 5.19s	remaining: 325ms
# 941:	learn: 0.2342143	total: 5.19s	remaining: 320ms
# 942:	learn: 0.2341602	total: 5.2s	remaining: 314ms
# 943:	learn: 0.2340362	total: 5.2s	remaining: 309ms
# 944:	learn: 0.2339644	total: 5.21s	remaining: 303ms
# 945:	learn: 0.2338533	total: 5.21s	remaining: 298ms
# 946:	learn: 0.2337738	total: 5.22s	remaining: 292ms
# 947:	learn: 0.2336725	total: 5.22s	remaining: 287ms
# 948:	learn: 0.2335905	total: 5.23s	remaining: 281ms
# 949:	learn: 0.2334377	total: 5.24s	remaining: 276ms
# 950:	learn: 0.2333405	total: 5.24s	remaining: 270ms
# 951:	learn: 0.2332667	total: 5.25s	remaining: 265ms
# 952:	learn: 0.2331755	total: 5.25s	remaining: 259ms
# 953:	learn: 0.2330940	total: 5.26s	remaining: 253ms
# 954:	learn: 0.2330373	total: 5.26s	remaining: 248ms
# 955:	learn: 0.2329265	total: 5.27s	remaining: 242ms
# 956:	learn: 0.2328452	total: 5.27s	remaining: 237ms
# 957:	learn: 0.2327308	total: 5.28s	remaining: 231ms
# 958:	learn: 0.2326663	total: 5.28s	remaining: 226ms
# 959:	learn: 0.2325753	total: 5.29s	remaining: 220ms
# 960:	learn: 0.2324827	total: 5.29s	remaining: 215ms
# 961:	learn: 0.2324315	total: 5.3s	remaining: 209ms
# 962:	learn: 0.2323650	total: 5.3s	remaining: 204ms
# 963:	learn: 0.2322776	total: 5.31s	remaining: 198ms
# 964:	learn: 0.2322023	total: 5.32s	remaining: 193ms
# 965:	learn: 0.2321669	total: 5.32s	remaining: 187ms
# 966:	learn: 0.2321092	total: 5.33s	remaining: 182ms
# 967:	learn: 0.2320382	total: 5.33s	remaining: 176ms
# 968:	learn: 0.2319765	total: 5.34s	remaining: 171ms
# 969:	learn: 0.2319004	total: 5.34s	remaining: 165ms
# 970:	learn: 0.2318419	total: 5.35s	remaining: 160ms
# 971:	learn: 0.2317560	total: 5.35s	remaining: 154ms
# 972:	learn: 0.2316904	total: 5.36s	remaining: 149ms
# 973:	learn: 0.2315738	total: 5.36s	remaining: 143ms
# 974:	learn: 0.2313978	total: 5.37s	remaining: 138ms
# 975:	learn: 0.2313303	total: 5.37s	remaining: 132ms
# 976:	learn: 0.2312144	total: 5.38s	remaining: 127ms
# 977:	learn: 0.2311660	total: 5.38s	remaining: 121ms
# 978:	learn: 0.2310587	total: 5.39s	remaining: 116ms
# 979:	learn: 0.2310005	total: 5.39s	remaining: 110ms
# 980:	learn: 0.2308872	total: 5.4s	remaining: 105ms
# 981:	learn: 0.2307609	total: 5.4s	remaining: 99.1ms
# 982:	learn: 0.2306594	total: 5.41s	remaining: 93.6ms
# 983:	learn: 0.2305745	total: 5.42s	remaining: 88.1ms
# 984:	learn: 0.2305208	total: 5.42s	remaining: 82.5ms
# 985:	learn: 0.2304711	total: 5.42s	remaining: 77ms
# 986:	learn: 0.2303919	total: 5.43s	remaining: 71.5ms
# 987:	learn: 0.2303080	total: 5.44s	remaining: 66ms
# 988:	learn: 0.2302436	total: 5.44s	remaining: 60.5ms
# 989:	learn: 0.2301815	total: 5.45s	remaining: 55ms
# 990:	learn: 0.2301214	total: 5.45s	remaining: 49.5ms
# 991:	learn: 0.2300570	total: 5.46s	remaining: 44ms
# 992:	learn: 0.2299658	total: 5.46s	remaining: 38.5ms
# 993:	learn: 0.2298723	total: 5.47s	remaining: 33ms
# 994:	learn: 0.2298017	total: 5.47s	remaining: 27.5ms
# 995:	learn: 0.2296967	total: 5.48s	remaining: 22ms
# 996:	learn: 0.2296310	total: 5.48s	remaining: 16.5ms
# 997:	learn: 0.2295572	total: 5.49s	remaining: 11ms
# 998:	learn: 0.2294798	total: 5.49s	remaining: 5.5ms
# 999:	learn: 0.2293692	total: 5.5s	remaining: 0us
#       model accuracy_score scale_method 0_precision 0_recall 1_precision  \
# 6  LightGBM           0.87           NA        0.88     0.97        0.79
# 4       GBM           0.86           NA        0.87     0.97        0.78
# 7  CatBoost           0.86           NA        0.88     0.96        0.76
# 3        RF           0.86           NA        0.87     0.97        0.77
# 5   XGBoost           0.85           NA        0.87     0.95        0.71
# 1       KNN           0.84           NA        0.86     0.95        0.67
# 0      LOGR           0.81           NA        0.82     0.98        0.70
# 2      CART           0.77           NA        0.86     0.85        0.45
#
#   1_recall
# 6     0.49
# 4     0.44
# 7     0.47
# 3     0.43
# 5     0.45
# 1     0.40
# 0     0.18
# 2     0.49

# %% [markdown]
# Now, let's have a look which model is best for us:

# %%
training_result
# Out:
#       model accuracy_score scale_method 0_precision 0_recall 1_precision  \
# 6  LightGBM           0.87           NA        0.88     0.97        0.79
# 4       GBM           0.86           NA        0.87     0.97        0.78
# 7  CatBoost           0.86           NA        0.88     0.96        0.76
# 3        RF           0.86           NA        0.87     0.97        0.77
# 5   XGBoost           0.85           NA        0.87     0.95        0.71
# 1       KNN           0.84           NA        0.86     0.95        0.67
# 0      LOGR           0.81           NA        0.82     0.98        0.70
# 2      CART           0.77           NA        0.86     0.85        0.45
#
#   1_recall
# 6     0.49
# 4     0.44
# 7     0.47
# 3     0.43
# 5     0.45
# 1     0.40
# 0     0.18
# 2     0.49

# %% [markdown]
# ## 9. Model Tunning

# %% [markdown]
# ### 9.1. XGBoost Tuning

# %%
xgb_model=XGBClassifier(silent=0, learning_rate=0.23, max_delta_step=5,
                            objective='reg:logistic',n_estimators=92, 
                            max_depth=5, eval_metric="logloss", gamma=3,base_score=0.5)
xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)
print(classification_report(y_test,y_pred,digits=2))
print("Accuracy score of Tuned XGBoost Regression: ", accuracy_score(y_test, y_pred))
# Out:
# [17:45:44] WARNING: /workspace/src/learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1588
#            1       0.78      0.49      0.60       412
#
#     accuracy                           0.87      2000
#    macro avg       0.83      0.72      0.76      2000
# weighted avg       0.86      0.87      0.85      2000
#
# Accuracy score of Tuned XGBoost Regression:  0.8655

# %% [markdown]
# ### 9.2. Random Forest Tuning

# %%
param_grid = {'max_depth': [3, 5, 6, 7, 8], 'max_features': [2,4,6,7,8,9],'n_estimators' : [50,100], 'min_samples_split': [3, 5, 6, 7]}
randFor_grid = GridSearchCV(RandomForestClassifier(), param_grid, cv = 5, refit = True, verbose = 0)
randFor_grid.fit(X_train,y_train)
best_model(randFor_grid)
# Out:
# 0.8609497342088804
# {'max_depth': 8, 'max_features': 6, 'min_samples_split': 3, 'n_estimators': 100}
# RandomForestClassifier(max_depth=8, max_features=6, min_samples_split=3)

# %% [markdown]
# Using the parameters and get final version accuracy score.

# %%
rnd_model = RandomForestClassifier(max_depth=8, max_features=6, min_samples_split=6,n_estimators=50)
rnd_model.fit(X_train, y_train)
y_pred = rnd_model.predict(X_test)
print(classification_report(y_test,y_pred,digits=2))
print("Accuracy score of tuned Random Forest model: ", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      1588
#            1       0.82      0.43      0.56       412
#
#     accuracy                           0.86      2000
#    macro avg       0.85      0.70      0.74      2000
# weighted avg       0.86      0.86      0.85      2000
#
# Accuracy score of tuned Random Forest model:  0.863

# %% [markdown]
# ### 9.3. LightGBM Tuning

# %%
lgbm_model = LGBMClassifier(silent = 0, learning_rate = 0.09, max_delta_step = 2, n_estimators = 100, boosting_type = 'gbdt',
                            max_depth = 10, eval_metric = "logloss", gamma = 3, base_score = 0.5)
lgbm_model.fit(X_train, y_train)
y_pred = lgbm_model.predict(X_test)
print(classification_report(y_test, y_pred, digits=2))
print("Accuracy score of tuned LightGBM model: ", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      1588
#            1       0.79      0.49      0.61       412
#
#     accuracy                           0.87      2000
#    macro avg       0.83      0.73      0.76      2000
# weighted avg       0.86      0.87      0.86      2000
#
# Accuracy score of tuned LightGBM model:  0.868

# %% [markdown]
# ## 10. Confussion Matrix

# %%
cfm = confusion_matrix(y_test, y_pred=y_pred)
plot_confusion_matrix(cfm, classes=['Non Churn','Churn'],
                      title='Churn Confusion matrix')


tn, fp, fn, tp = cfm.ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
# Out:
# Confusion matrix, without normalization
# [[1533   55]
#  [ 209  203]]
# True Negatives:  1533
# False Positives:  55
# False Negatives:  209
# True Positives:  203

# %%
#!pip install scikit-plot

# %% [markdown]
# ## 11. ROC Curve

# %%
import scikitplot as skplt
y_pred_proba = lgbm_model.predict_proba(X_test)
skplt.metrics.plot_roc_curve(y_test, y_pred_proba, figsize=(8,8))

plt.show()

# %% [markdown]
# # 12. Feature Importance

# %%
feature_index = df_encoded.loc[:, df_encoded.columns != dependent_variable_name]

feature_importance = pd.Series(lgbm_model.feature_importances_, 
                               index=feature_index.columns).sort_values(ascending=False)
sns.barplot(x = feature_importance, y = feature_importance.index, color='r', saturation=1)
plt.xlabel('Variable Severity Scores')
plt.ylabel('Variables')
plt.title('Variable Severity Levels')
plt.show()

# %% [markdown]
# # 13. Conclusion
#
#
# - Our aim in this project was to develop a churn prediction model using machine learning algorithms.
# - There were 10000 rows in the data set and there were no missing values. and the dataset consisted of 13 variables.
#
#
# - The following conclusions came from the analysis on the features:
#
#     * Most customers who using products 3 and 4 stopped working with the bank. In fact, all customers using product number 4 were gone.
#     * Customers between the ages of 40 and 65 were more likely to quit the bank.
#     * Those who had a credit score below 450 had high abandonment rates.
#     * Predictions were made with a total of 8 classification models. The highest head was taken with LightGBM method.
#     * Accuracy and cross validation scores were calculated for each model and results were displayed.
#
#
#
# #### Note:
#
#     * After this notebook, my aim is to prepare 'kernel' which is 'not clear' data set.
#
#     * If you have any suggestions, please could you write for me? I wil be happy for comment and critics!
#
#     * Thank you for your suggestion and votes ;)
